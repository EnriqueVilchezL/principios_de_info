# %% [markdown]
# # Principios de Informática: Laboratorio de Subrutinas 🧩
# ### Construyendo programas modulares y reutilizables
#
# **Curso:** Principios de Informática
#
# ---
#
# ## Instrucciones 🚧
#
# ### 1.	Objetivo
#   * El objetivo es que usted aplique los conceptos vistos en clase utilizando Python en un entorno interactivo.
#
# ### 2.	Ejecución
#   * Lea atentamente cada problema o ejercicio que se le plantee en las celdas de texto (Markdown).
#   * Escriba su código en las celdas de código justo debajo de cada enunciado.
#   * Ejecute cada celda para verificar que su código funcione correctamente.
#   * Puede añadir celdas adicionales si lo considera necesario para dividir el código o realizar pruebas.
#   * Se le recuerda que está **estrictamente prohibido** utilizar herramientas de inteligencia artificial para hacer sus soluciones. Puede ver cómo desactivar **Gemini** en Colab en este link: [![Desactivar Gemini](https://colab.research.google.com/assets/colab-badge.svg)](https://githubtocolab.com/EnriqueVilchezL/principios_de_info/blob/main/1_fundamentos_de_la_programacion/desactivar_gemini.ipynb).
#
# ### 3.	Documentación
#   * Si lo considera necesario, utilice celdas de texto (Markdown) para agregar comentarios, explicaciones o respuestas a preguntas.
#   * Preferiblemente agregue comentarios significativos que ilustren el proceso en el código para hacerlo más claro, usando `#` o `"""Comentatio acá"""` en sus celdas de código.
#   * Organice el notebook de manera clara con títulos, subtítulos y descripciones pertinentes.
#
# ### 4.	Entrega
#   * Guarde su notebook con el nombre `tarea_#_carne.ipynb`. Por ejemplo: `tarea_02_c18477.ipynb`.
#   * Descargue el archivo desde Colab (`Archivo` -> `Descargar` > `Descargar .ipynb`).
#   * Entregue el archivo `.ipynb`. Este laboratorio debe entregarse a través de Mediación Virtual.
#
# ### 5.	Recomendaciones
#   * Ponga comentarios en su código para facilitar su comprensión.
#   * Utilice nombres claros y significativos para variables y funciones.
#   * Verifique que todas las celdas se ejecuten sin errores.
#   * Mantenga el notebook organizado y bien documentado.
#   * No dude en consultar en caso de dudas o dificultades.
#
# ### 6.	Evaluación
#   * Se evaluará que el código funcione correctamente y resuelva los problemas planteados.
#   * Se tomará en cuenta la claridad en la documentación y la organización del notebook.
#   * Se tomará en cuenta la nomenclatura de variables y funciones creadas. Estos nombres **deben** ser significativos. Por ejemplo, en vez de nombrar una variable `a`, nombrela con algo que represente su significado, como `nombre`, `edad_de_persona`, etc. Esto se exceptúa en los ejercicios en donde el mismo enunciado nombra las variables que se deben usar.
#   * **Debe poder ejecutarse el notebook de forma secuencial y que funcione correctamente (no se aceptará la ejecución de celdas en desorden para obtener el resultado deseado).**
#   * Cada ejercicio debe resolverse de manera **independiente**. Puede usar los mismos nombres de variables o funciones en distintos ejercicios, pero los valores de las variables (o resultados previos) **no se pueden reutilizar entre ejercicios salvo que se indique lo contrario en el enunciado del ejercicio**.
#
# #### Ejemplo de independencia entre ejercicios
#
# Lo incorrecto 🚫:
#
# | Ejercicio | Código | Comentario |
# |------------|-----------|--------|
# | 1 | x = 10<br>y = 5<br>suma = x + y<br>print(suma) | Calcula la suma correctamente |
# | 2 | doble = suma * 2<br>print(doble) | Reutiliza 'suma' del ejercicio 1, lo cual **no está permitido** |
#
# Lo correcto ✅:
#
# | Ejercicio | Código | Comentario |
# |------------|-----------|--------|
# | 1 | x = 10<br>y = 5<br>suma = x + y<br>print(suma) | Calcula la suma correctamente |
# | 2 | suma = 7 + 3<br>doble = suma * 2<br>print(doble) | No eutiliza 'suma' del ejercicio 1. Cada ejercicio se resuelve de manera independiente |

# %% [markdown]
# # Pruebas automáticas
#
# **EJECUTE LA CELDA DE ABAJO ANTES DE EMPEZAR A EJECUTAR SU CÓDIGO**
# Esto sirve para que pueda ejecutar casos de prueba sobre su código.
#
# ---

# %%
# !pip install --upgrade notebook-cell-tester --q

# %% [markdown]
# ---
#
# **Ejercicio 1**
#
# Escriba un programa que dibuje el un patrón de triángulos (con el caracter *) cada vez más pequeños por medio de un número de anchura del triángulo dado por el usuario. Por ejemplo, si la anchura introducida es 3, la salida del programa tiene que ser:
#
# ```
# Anchura del triángulo: 3
# *
# * *
# * * *
# * *
# *
#
# *
# * *
# *
#
# *
# ```
#
# Note que el primer triángulo tiene *** en medio, pues la anchura es 3. El siguiente tiene ** en medio por decrementar la anchura a 2. Y el último tiene * en medio por decrementar la anchura a 1, que es lo mínimo.
#
# **Tiene** que hacer una función llamada `dibujar_triangulo`, que reciba un número e imprima un único triángulo de anchura igual al número pasado por parámetro. Utilice esta función para resolver el problema completo usando estructuras de control de flujo.
#
# Haga una función llamada `main`, en donde ponga el código principal de su programa.
#
# Asegúrese de que su programa sea resistente a errores de entrada.
#
# **Sus funciones deben tener docstring estilo Google**.
#
# ---

# %%
# Acá su código

# %%
#@title Pruebas automáticas (solo ejecutar, no modificar)
from notebook_cell_tester.tester import ColabTestFramework, TestCase

tester = ColabTestFramework()

# Definir los casos de prueba
tests = [
    # ===== VALIDACIÓN DE ESTRUCTURA DEL CÓDIGO =====
    TestCase(
        name="Define función dibujar_triangulo",
        test_type="regex",
        pattern=r"def\s+dibujar_triangulo\s*\(",
        error_message="Debe definir una función llamada 'dibujar_triangulo' que reciba un número como parámetro"
    ),

    TestCase(
        name="Define función main",
        test_type="regex",
        pattern=r"def\s+main\s*\(",
        error_message="Debe definir una función llamada 'main' que contenga el código principal del programa"
    ),

    TestCase(
        name="La función dibujar_triangulo tiene docstring estilo Google",
        test_type="regex",
        pattern=r'def\s+dibujar_triangulo\s*\([^)]*\)\s*:\s*["\'][\s\S]*?(Args:|Returns:|Parameters:)',
        error_message="La función 'dibujar_triangulo' debe tener un docstring estilo Google (con Args:, Returns:, etc.)"
    ),

    TestCase(
        name="Llama a la función main",
        test_type="regex",
        pattern=r"main\s*\(\s*\)",
        error_message="Debe llamar a la función 'main()' para ejecutar el programa principal"
    ),

    TestCase(
        name="Usa ciclo for para dibujar líneas",
        test_type="regex",
        pattern=r"for\s+\w+\s+in\s+",
        error_message="Debe usar un ciclo 'for' para dibujar las líneas del triángulo"
    ),

    TestCase(
        name="Usa ciclo while para decrementar anchura",
        test_type="regex",
        pattern=r"while\s+",
        error_message="Debe usar un ciclo 'while' para decrementar la anchura y dibujar múltiples triángulos"
    ),

    TestCase(
        name="No usa while True",
        test_type="not_regex",
        pattern=r"while\s*True\s*:",
        error_message="No debe usar un ciclo 'while' con la condición True para mostrar el menú repetidamente hasta que el usuario elija salir"
    ),

    TestCase(
        name="No usa break",
        test_type="not_regex",
        pattern=r"break",
        error_message="No debe usar un break para romper el ciclo"
    ),

    TestCase(
        name="Imprime asteriscos (*)",
        test_type="regex",
        pattern=r"[*]|['\"]\*['\"]",
        error_message="Debe usar el carácter asterisco (*) para dibujar los triángulos"
    ),

    TestCase(
        name="Usa print() para mostrar el patrón",
        test_type="regex",
        pattern=r"print\s*\(",
        error_message="Debe usar print() para mostrar las líneas del triángulo"
    ),

    TestCase(
        name="Usa input() para solicitar anchura",
        test_type="regex",
        pattern=r"input\s*\(",
        error_message="Debe usar input() para solicitar la anchura del triángulo al usuario"
    ),

    TestCase(
        name="Llama a la función dibujar_triangulo desde main",
        test_type="regex",
        pattern=r"dibujar_triangulo\s*\(",
        error_message="Debe llamar a la función 'dibujar_triangulo' desde el código principal (función main)"
    ),

    TestCase(
        name="No asigna la anchura directamente",
        test_type="not_regex",
        pattern=r"^\s*anchura\s*=\s*\d+\s*$",
        error_message="No debe asignar la anchura directamente. Debe obtenerse del usuario con input()"
    ),

    # ===== PRUEBAS DE LA FUNCIÓN dibujar_triangulo =====
    TestCase(
        name="Función dibujar_triangulo con anchura 1",
        test_type="regex_output",
        function_name="dibujar_triangulo",
        inputs=[1],
        pattern=r"\*"
    ),

    TestCase(
        name="Función dibujar_triangulo con anchura 2",
        test_type="regex_output",
        function_name="dibujar_triangulo",
        inputs=[2],
        pattern=r"\*\s?\n\* \*\s?\n\*"
    ),

    TestCase(
        name="Función dibujar_triangulo con anchura 3",
        test_type="regex_output",
        function_name="dibujar_triangulo",
        inputs=[3],
        pattern=r"\*\s?\n\* \*\s?\n\* \* \*\s?\n\* \*\s?\n\*\s?"
    ),

    # ===== CASOS DE PRUEBA DEL PROGRAMA COMPLETO (función main) =====
    TestCase(
        name="Programa completo con anchura 1",
        test_type="regex_output",
        stdin_input="1\n",
        pattern=r"\*\s?"
    ),

    TestCase(
        name="Programa completo con anchura 2",
        test_type="regex_output",
        stdin_input="2\n",
        pattern=r"\*\s?\n\* \*\s?\n\*\s?\n\n\*\s?"
    ),

    TestCase(
        name="Programa completo con anchura 3",
        test_type="regex_output",
        stdin_input="3\n",
        pattern=r"\*\s?\n\* \*\s?\n\* \* \*\s?\n\* \*\s?\n\*\s?\n\n\*\s?\n\* \*\s?\n\*\s?\n\n\*\s?"
    ),

    # ===== VALIDACIÓN DE ENTRADA INCORRECTA =====
    TestCase(
        name="Rechaza entrada con texto y vuelve a pedir",
        test_type="regex_output",
        stdin_input="abc\n3\n",
        pattern=r"\*\s?\n\* \*\s?\n\* \* \*\s?\n\* \*\s?\n\*\s?\n\n\*\s?\n\* \*\s?\n\*\s?\n\n\*\s?"
    ),

    TestCase(
        name="Rechaza entrada con número decimal y vuelve a pedir",
        test_type="regex_output",
        stdin_input="3.5\n3\n",
        pattern=r"\*\s?\n\* \*\s?\n\* \* \*\s?\n\* \*\s?\n\*\s?\n\n\*\s?\n\* \*\s?\n\*\s?\n\n\*\s?"
    ),

    TestCase(
        name="Rechaza entrada negativa y vuelve a pedir",
        test_type="regex_output",
        stdin_input="-5\n3\n",
        pattern=r"\*\s?\n\* \*\s?\n\* \* \*\s?\n\* \*\s?\n\*\s?\n\n\*\s?\n\* \*\s?\n\*\s?\n\n\*\s?"
    ),

    TestCase(
        name="Rechaza entrada vacía y vuelve a pedir",
        test_type="regex_output",
        stdin_input="\n3\n",
        pattern=r"\*\s?\n\* \*\s?\n\* \* \*\s?\n\* \*\s?\n\*\s?\n\n\*\s?\n\* \*\s?\n\*\s?\n\n\*\s?"
    ),
]

# Ejecutar las pruebas
tester.run_tests(tests)

# Mostrar resultados
tester.display_results()

# %% [markdown]
# ---
#
# **Ejercicio 2**
#
# Un ingeniero está diseñando un sistema de seguridad para varios vehículos. Para cada vehículo, se conoce su masa y su velocidad. La **energía cinética** se calcula como:
#
# $$
# E_c = \frac{1}{2} m v^2
# $$
#
# El sistema tiene un **límite seguro de energía** de 200,000 Joules. Si la energía cinética de un vehículo supera este límite, se considera que el vehículo está en “zona de riesgo”.
#
# **Tarea:**
#
# 1. Escriba una función `energia_cinetica(masa, velocidad)` que devuelva la energía cinética de un vehículo.
# 2. Escriba una función `evaluar_seguridad(masa, velocidad, limite)` que utilice `energia_cinetica` y devuelva:
#    - `"Seguro"` si la energía está por debajo del límite
#    - `"Zona de riesgo"` si la energía supera el límite
# 3. Cree un programa que:
#    - Solicite al usuario el número de vehículos.
#    - Para cada vehículo, pida masa y velocidad.
#    - Evalúe la energía cinética y la seguridad del vehículo usando las funciones. Muestre el estado del vehículo justo después de pedir sus datos.
#    - Al final, muestre un **resumen** con:
#      - Cuántos están en zona de riesgo
#
# Un ejemplo de una salida válida del programa sería:
#
# ```
# Ingrese el número de vehículos: 3
#
# Vehículo 1:
#   Masa (kg): 1500
#   Velocidad (m/s): 20
#   Energía cinética: 300000.0 J
#   Estado: Zona de riesgo
#
# Vehículo 2:
#   Masa (kg): 800
#   Velocidad (m/s): 10
#   Energía cinética: 40000.0 J
#   Estado: Seguro
#
# Vehículo 3:
#   Masa (kg): 1200
#   Velocidad (m/s): 15
#   Energía cinética: 135000.0 J
#   Estado: Seguro
#
# Resumen:
# - Vehículos en zona de riesgo: 1
# ```
#
# **Sus funciones deben tener docstring estilo Google**.
#
# ---

# %%
# Acá su código

# %%
#@title Pruebas automáticas (solo ejecutar, no modificar)
from notebook_cell_tester.tester import ColabTestFramework, TestCase

# Inicializar el framework
tester = ColabTestFramework()

# Definir los casos de prueba
tests = [
    # ===== VALIDACIÓN DE ESTRUCTURA DEL CÓDIGO =====
    TestCase(
        name="Define función energia_cinetica",
        test_type="regex",
        pattern=r"def\s+energia_cinetica\s*\(",
        error_message="Debe definir una función llamada 'energia_cinetica' que calcule la energía cinética"
    ),

    TestCase(
        name="Define función evaluar_seguridad",
        test_type="regex",
        pattern=r"def\s+evaluar_seguridad\s*\(",
        error_message="Debe definir una función llamada 'evaluar_seguridad' que evalúe si un vehículo está en zona de riesgo"
    ),

    TestCase(
        name="La función energia_cinetica tiene docstring estilo Google",
        test_type="regex",
        pattern=r'def\s+energia_cinetica\s*\([^)]*\)\s*:\s*["\'][\s\S]*?(Args:|Returns:|Parameters:)',
        error_message="La función 'energia_cinetica' debe tener un docstring estilo Google (con Args:, Returns:, etc.)"
    ),

    TestCase(
        name="La función evaluar_seguridad tiene docstring estilo Google",
        test_type="regex",
        pattern=r'def\s+evaluar_seguridad\s*\([^)]*\)\s*:\s*["\'][\s\S]*?(Args:|Returns:|Parameters:)',
        error_message="La función 'evaluar_seguridad' debe tener un docstring estilo Google (con Args:, Returns:, etc.)"
    ),

    TestCase(
        name="Usa la fórmula correcta de energía cinética",
        test_type="regex",
        pattern=r"(0\.5|1/2|\(1\s*/\s*2\)).*\*.*masa.*\*.*velocidad.*\*\*\s*2|(0\.5|1/2|\(1\s*/\s*2\)).*\*.*velocidad.*\*\*\s*2.*\*.*masa",
        error_message="Debe usar la fórmula correcta de energía cinética: Ec = (1/2) * masa * velocidad²"
    ),

    TestCase(
        name="Usa ciclo for para procesar múltiples vehículos",
        test_type="regex",
        pattern=r"for\s+\w+\s+in\s+range",
        error_message="Debe usar un ciclo 'for' con range() para procesar múltiples vehículos"
    ),

    TestCase(
        name="No usa while True",
        test_type="not_regex",
        pattern=r"while\s*True\s*:",
        error_message="No debe usar un ciclo 'while' con la condición True para mostrar el menú repetidamente hasta que el usuario elija salir"
    ),

    TestCase(
        name="No usa break",
        test_type="not_regex",
        pattern=r"break",
        error_message="No debe usar un break para romper el ciclo"
    ),

    TestCase(
        name="Usa input() para solicitar datos",
        test_type="regex",
        pattern=r"input\s*\(",
        error_message="Debe usar input() para solicitar el número de vehículos, masa y velocidad"
    ),

    TestCase(
        name="Llama a la función energia_cinetica",
        test_type="regex",
        pattern=r"energia_cinetica\s*\(",
        error_message="Debe llamar a la función 'energia_cinetica' desde el código principal"
    ),

    TestCase(
        name="Llama a la función evaluar_seguridad",
        test_type="regex",
        pattern=r"evaluar_seguridad\s*\(",
        error_message="Debe llamar a la función 'evaluar_seguridad' desde el código principal"
    ),

    TestCase(
        name="Usa contador para vehículos en riesgo",
        test_type="regex",
        pattern=r"(riesgo|contador|count).*(\+=|=.*\+\s*1)",
        error_message="Debe usar un contador para llevar el registro de vehículos en zona de riesgo"
    ),

    TestCase(
        name="Muestra resumen al final",
        test_type="regex",
        pattern=r"(Resumen|resumen|RESUMEN)",
        error_message="Debe mostrar un resumen al final con el total de vehículos en zona de riesgo"
    ),

    TestCase(
        name="No asigna valores directamente a masa o velocidad",
        test_type="not_regex",
        pattern=r"^\s*(masa|velocidad)\s*=\s*\d+\.?\d*\s*$",
        error_message="No debe asignar valores directamente a masa o velocidad. Deben obtenerse del usuario con input()"
    ),

    # ===== PRUEBAS DE LA FUNCIÓN energia_cinetica =====
    TestCase(
        name="Función energia_cinetica: masa=1000, v=10",
        test_type="return",
        function_name="energia_cinetica",
        inputs=[1000, 10],
        expected=50000.0
    ),

    TestCase(
        name="Función energia_cinetica: masa=1500, v=20",
        test_type="return",
        function_name="energia_cinetica",
        inputs=[1500, 20],
        expected=300000.0
    ),

    TestCase(
        name="Función energia_cinetica: masa=800, v=10",
        test_type="return",
        function_name="energia_cinetica",
        inputs=[800, 10],
        expected=40000.0
    ),

    TestCase(
        name="Función energia_cinetica: masa=1200, v=15",
        test_type="return",
        function_name="energia_cinetica",
        inputs=[1200, 15],
        expected=135000.0
    ),

    TestCase(
        name="Función energia_cinetica: masa=2000, v=0 (vehículo detenido)",
        test_type="return",
        function_name="energia_cinetica",
        inputs=[2000, 0],
        expected=0.0
    ),

    # ===== PRUEBAS DE LA FUNCIÓN evaluar_seguridad =====
    TestCase(
        name="Función evaluar_seguridad: Seguro (100000 J < 200000)",
        test_type="return",
        function_name="evaluar_seguridad",
        inputs=[1000, 14.14, 200000],
        expected="Seguro"
    ),

    TestCase(
        name="Función evaluar_seguridad: Zona de riesgo (300000 J > 200000)",
        test_type="return",
        function_name="evaluar_seguridad",
        inputs=[1500, 20, 200000],
        expected="Zona de riesgo"
    ),

    TestCase(
        name="Función evaluar_seguridad: Seguro (40000 J < 200000)",
        test_type="return",
        function_name="evaluar_seguridad",
        inputs=[800, 10, 200000],
        expected="Seguro"
    ),

    TestCase(
        name="Función evaluar_seguridad: Justo en el límite (200000 J)",
        test_type="return",
        function_name="evaluar_seguridad",
        inputs=[1000, 20, 200000],
        expected="Seguro"
    ),

    # ===== CASOS DE PRUEBA DEL PROGRAMA COMPLETO =====
    TestCase(
        name="Programa con 1 vehículo seguro",
        test_type="regex_output",
        stdin_input="1\n800\n10\n",
        pattern=r"40000.*Seguro.*0"
    ),

    TestCase(
        name="Programa con 1 vehículo en zona de riesgo",
        test_type="regex_output",
        stdin_input="1\n1500\n20\n",
        pattern=r"300000.*Zona de riesgo.*1"
    ),

    TestCase(
        name="Programa con 3 vehículos (ejemplo del enunciado)",
        test_type="regex_output",
        stdin_input="3\n1500\n20\n800\n10\n1200\n15\n",
        pattern=r"300000.*Zona de riesgo.*40000.*Seguro.*135000.*Seguro.*1"
    ),

    TestCase(
        name="Programa con 2 vehículos, ambos seguros",
        test_type="regex_output",
        stdin_input="2\n1000\n10\n800\n10\n",
        pattern=r"50000.*Seguro.*40000.*Seguro.*0"
    ),

    TestCase(
        name="Programa con 2 vehículos, ambos en riesgo",
        test_type="regex_output",
        stdin_input="2\n2000\n20\n1500\n20\n",
        pattern=r"400000.*Zona de riesgo.*300000.*Zona de riesgo.*2"
    ),

    TestCase(
        name="Programa con 4 vehículos mixtos",
        test_type="regex_output",
        stdin_input="4\n1000\n10\n2000\n20\n500\n15\n1800\n18\n",
        pattern=r"50000.*Seguro.*400000.*Zona de riesgo.*56250.*Seguro.*291600.*Zona de riesgo.*2"
    ),

    # ===== VALIDACIÓN DE ENTRADA INCORRECTA =====
    TestCase(
        name="Rechaza texto en número de vehículos",
        test_type="regex_output",
        stdin_input="abc\n1\n800\n10\n",
        pattern=r"40000.*Seguro.*0"
    ),

    TestCase(
        name="Rechaza texto en masa",
        test_type="regex_output",
        stdin_input="1\nxyz\n800\n10\n",
        pattern=r"40000.*Seguro.*0"
    ),

    TestCase(
        name="Rechaza texto en velocidad",
        test_type="regex_output",
        stdin_input="1\n800\nabc\n10\n",
        pattern=r"40000.*Seguro.*0"
    ),

    TestCase(
        name="Rechaza valores negativos en masa",
        test_type="regex_output",
        stdin_input="1\n-800\n800\n10\n",
        pattern=r"40000.*Seguro.*0"
    ),

    TestCase(
        name="Rechaza valores negativos en velocidad",
        test_type="regex_output",
        stdin_input="1\n800\n-10\n10\n",
        pattern=r"40000.*Seguro.*0"
    ),

    # ===== CASOS ESPECIALES =====
    TestCase(
        name="Vehículo con velocidad 0 (detenido)",
        test_type="regex_output",
        stdin_input="1\n2000\n0\n",
        pattern=r"0.*Seguro.*0"
    ),

    TestCase(
        name="Vehículo justo en el límite de 200000 J",
        test_type="regex_output",
        stdin_input="1\n1000\n20\n",
        pattern=r"200000.*Seguro.*0"
    ),
]

# Ejecutar las pruebas
tester.run_tests(tests)

# Mostrar resultados
tester.display_results()
