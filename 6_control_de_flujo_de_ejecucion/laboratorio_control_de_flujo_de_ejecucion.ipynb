# %% [markdown]
# # Principios de Informática: Laboratorio de Control de Flujo de Ejecución 🚦
# ### Dándole a un programa la capacidad de decidir y repetir
#
# **Curso:** Principios de Informática
#
# ---
#
# ## Instrucciones 🚧
#
# ### 1.	Objetivo
#   * El objetivo es que usted aplique los conceptos vistos en clase utilizando Python en un entorno interactivo.
#
# ### 2.	Ejecución
#   * Lea atentamente cada problema o ejercicio que se le plantee en las celdas de texto (Markdown).
#   * Escriba su código en las celdas de código justo debajo de cada enunciado.
#   * Ejecute cada celda para verificar que su código funcione correctamente.
#   * Puede añadir celdas adicionales si lo considera necesario para dividir el código o realizar pruebas.
#   * Se le recuerda que está **estrictamente prohibido** utilizar herramientas de inteligencia artificial para hacer sus soluciones. Puede ver cómo desactivar **Gemini** en Colab en este link: [![Desactivar Gemini](https://colab.research.google.com/assets/colab-badge.svg)](https://githubtocolab.com/EnriqueVilchezL/principios_de_info/blob/main/1_fundamentos_de_la_programacion/desactivar_gemini.ipynb).
#
# ### 3.	Documentación
#   * Si lo considera necesario, utilice celdas de texto (Markdown) para agregar comentarios, explicaciones o respuestas a preguntas.
#   * Preferiblemente agregue comentarios significativos que ilustren el proceso en el código para hacerlo más claro, usando `#` o `"""Comentatio acá"""` en sus celdas de código.
#   * Organice el notebook de manera clara con títulos, subtítulos y descripciones pertinentes.
#
# ### 4.	Entrega
#   * Guarde su notebook con el nombre `laboratorio_#_carne.ipynb`. Por ejemplo: `laboratorio_01_c18477.ipynb`.
#   * Descargue el archivo desde Colab (`Archivo` -> `Descargar` > `Descargar .ipynb`).
#   * Entregue el archivo `.ipynb`. Este laboratorio debe entregarse a través de Mediación Virtual.
#
# ### 5.	Recomendaciones
#   * Ponga comentarios en su código para facilitar su comprensión.
#   * Utilice nombres claros y significativos para variables y funciones.
#   * Verifique que todas las celdas se ejecuten sin errores.
#   * Mantenga el notebook organizado y bien documentado.
#   * No dude en consultar en caso de dudas o dificultades.
#
# ### 6.	Evaluación
#   * Se evaluará que el código funcione correctamente y resuelva los problemas planteados.
#   * Se tomará en cuenta la claridad en la documentación y la organización del notebook.
#   * Se tomará en cuenta la nomenclatura de variables y funciones creadas. Estos nombres **deben** ser significativos. Por ejemplo, en vez de nombrar una variable `a`, nombrela con algo que represente su significado, como `nombre`, `edad_de_persona`, etc. Esto se exceptúa en los ejercicios en donde el mismo enunciado nombra las variables que se deben usar.
#   * **Debe poder ejecutarse el notebook de forma secuencial y que funcione correctamente (no se aceptará la ejecución de celdas en desorden para obtener el resultado deseado).**
#   * Cada ejercicio debe resolverse de manera **independiente**. Puede usar los mismos nombres de variables o funciones en distintos ejercicios, pero los valores de las variables (o resultados previos) **no se pueden reutilizar entre ejercicios salvo que se indique lo contrario en el enunciado del ejercicio**.
#
# #### Ejemplo de independencia entre ejercicios
#
# Lo incorrecto 🚫:
#
# | Ejercicio | Código | Comentario |
# |------------|-----------|--------|
# | 1 | x = 10<br>y = 5<br>suma = x + y<br>print(suma) | Calcula la suma correctamente |
# | 2 | doble = suma * 2<br>print(doble) | Reutiliza 'suma' del ejercicio 1, lo cual **no está permitido** |
#
# Lo correcto ✅:
#
# | Ejercicio | Código | Comentario |
# |------------|-----------|--------|
# | 1 | x = 10<br>y = 5<br>suma = x + y<br>print(suma) | Calcula la suma correctamente |
# | 2 | suma = 7 + 3<br>doble = suma * 2<br>print(doble) | No eutiliza 'suma' del ejercicio 1. Cada ejercicio se resuelve de manera independiente |

# %% [markdown]
# # Pruebas automáticas
#
# **EJECUTE LA CELDA DE ABAJO ANTES DE EMPEZAR A EJECUTAR SU CÓDIGO**
# Esto sirve para que pueda ejecutar casos de prueba sobre su código.
#
# ---

# %%
# !pip install --upgrade notebook-cell-tester --q

# %% [markdown]
# ---
#
# **Ejercicio 1**
#
# En un cultivo se introducen 500 bacterias. Durante cierto tiempo, las bacterias se reproducen, y al cabo de $t$ minutos la cantidad de bacterias está dada por la ecuación:
#
# $$
# f(t) = a \cdot t^2 + b \cdot t + 500
# $$
#
# Donde $a$ y $b$ son números que pueden cambiar dependiendo del clima de la región del cultivo. Debe solicitar estos números al usuario.
#
# Un biólogo necesita determinar **si la población de bacterias va a alcanzar 0 en algún momento** (esto es resolver la ecuación $0 = a \cdot t^2 + b \cdot t + 500$). Para ello:
#
# 1. Calcule el **determinante**:
#
# $$
# \Delta = b^2 - 4 \cdot a \cdot 500
# $$
#
# 2. Determine el número de soluciones reales. Recuerde que si $\Delta > 0$ hay dos soluciones, si $\Delta = 0$ hay una solución, y si $\Delta < 0$ no hay ninguna solución.
#
# 3. Si existe alguna solución, calcule las soluciones con:
#
# $$
# t = \frac{-b \pm \sqrt{\Delta}}{2a}
# $$
#
# 4. Si $a = 0$, muestre un mensaje de error y vuelva a pedir $a$ hasta que el usuario ingrese un número distinto a 0.
#
# Tome en cuenta que si alguna solución es negativa, entonces no se considera una solución, ya que el tiempo no puede ser negativo.
#
# Ejemplos:
#
# | a     | b    | Hay solución | Soluciones (t en minutos)      |
# |-------|------|--------------|--------------------------------|
# | -1    | 30   | Sí           | 41.925                          |
# | -2    | 50   | Sí           | 32.655                          |
# | -1    | 10   | Sí           | 27.912                          |
# | 2     | 5    | No           | -                               |
#
# **NOTA**: Su programa debe ASEGURARSE de que se ingresen los tipos de datos correctos. Si el usuario ingresa un tipo de dato incorrecto, pídalo nuevamente HASTA que lo ingrese de forma correcta.
#
# ---

# %%
# Acá su código

# %%
#@title Pruebas automáticas (solo ejecutar, no modificar)
from notebook_cell_tester.tester import ColabTestFramework, TestCase

# Inicializar el framework
tester = ColabTestFramework()

# Definir los casos de prueba
tests = [
    # ===== VALIDACIÓN DE ESTRUCTURA DEL CÓDIGO =====
    TestCase(
        name="Usa ciclo while para validación",
        test_type="regex",
        pattern=r"while\s+",
        error_message="Debe usar un ciclo 'while' para validar que se ingresen datos correctos"
    ),

    TestCase(
        name="No usa while True",
        test_type="not_regex",
        pattern=r"while\s*True\s*:",
        error_message="No debe usar un ciclo 'while' con la condición True para mostrar el menú repetidamente hasta que el usuario elija salir"
    ),

    TestCase(
        name="No usa break",
        test_type="not_regex",
        pattern=r"break",
        error_message="No debe usar un break para romper el ciclo"
    ),

    TestCase(
        name="Usa if/elif/else para decisiones",
        test_type="regex",
        pattern=r"if\s+",
        error_message="Debe usar condicionales 'if' para tomar decisiones basadas en el determinante"
    ),

    TestCase(
        name="Usa la función input()",
        test_type="regex",
        pattern=r"input\s*\(",
        error_message="Debe usar input() para solicitar los valores de a y b al usuario"
    ),

    TestCase(
        name="Calcula el determinante",
        test_type="regex",
        pattern=r"b\s*\*\*\s*2.*-.*4.*\*.*a.*\*.*500|b\s*\*\s*b.*-.*4.*\*.*a.*\*.*500",
        error_message="Debe calcular el determinante usando la fórmula: b² - 4*a*500"
    ),

    TestCase(
        name="Usa sqrt o exponente 0.5",
        test_type="regex",
        pattern=r"sqrt\(|math\.sqrt\(|\*\*\s*0\.5|\*\*\s*\(0\.5\)|\*\*\s*\(1/2\)",
        error_message="Debe calcular la raíz cuadrada del determinante para encontrar las soluciones"
    ),

    TestCase(
        name="No asigna números directamente a variables principales",
        test_type="not_regex",
        pattern=r"^\s*(a|b|delta|determinante)\s*=\s*-?\d+\.?\d*\s*$",
        error_message="No debe asignar valores numéricos directamente a las variables a, b o delta. Estos valores deben obtenerse del usuario o calcularse."
    ),

    TestCase(
        name="Valida que a no sea 0",
        test_type="regex",
        pattern=r"(a\s*==\s*0|a\s*!=\s*0|\s*0\s*==\s*a|\s*0\s*!=\s*a)",
        error_message="Debe validar que 'a' sea diferente de 0, ya que es una ecuación cuadrática"
    ),

    # ===== CASOS DE PRUEBA CON SOLUCIONES REALES =====
    TestCase(
        name="Caso 1: a=-1, b=30 (solución: 41.926)",
        test_type="regex_output",
        stdin_input="-1\n30",
        pattern=r"41.926"
    ),

    TestCase(
        name="Caso 2: a=-2, b=50 (solución: 32.656)",
        test_type="regex_output",
        stdin_input="-2\n50",
        pattern=r"32.656"
    ),

    TestCase(
        name="Caso 3: a=-1, b=10 (solución: 27.913)",
        test_type="regex_output",
        stdin_input="-1\n10",
        pattern=r"27.913"
    ),

    TestCase(
        name="Caso 4: a=2, b=5 (sin solución)",
        test_type="regex_output",
        stdin_input="2\n5",
        pattern="No"
    ),

    # ===== VALIDACIÓN DE ENTRADA DE DATOS =====
    TestCase(
        name="Maneja entrada incorrecta y la vuelve a pedir",
        test_type="regex_output",
        stdin_input="abc\n-1\nxyz\n30",
        pattern=r"41.926"
    ),

    TestCase(
        name="Rechaza a=0 y vuelve a pedirlo",
        test_type="regex_output",
        stdin_input="0\n-1\n30",
        pattern=r"41.926"
    ),

    # ===== CASOS EDGE =====
    TestCase(
        name="Caso con determinante = 0 (una solución)",
        test_type="regex_output",
        stdin_input="-1\n-44.72",
        pattern=r"9.262"
    ),

    TestCase(
        name="Caso con dos soluciones, una negativa (solo mostrar positiva)",
        test_type="regex_output",
        stdin_input="-1\n20",
        pattern=r"34.495"
    ),
]

# Ejecutar las pruebas
tester.run_tests(tests)

# Mostrar resultados
tester.display_results()

# %% [markdown]
# ---
#
# **Ejercicio 2**
#
# Construya un programa que tome como entrada una hilera de texto inicial compuesto de números y construya otras dos hileras de texto: una con los números pares contenidos en la hilera inicial y otra con los números impares.
#
# Estas dos nuevas hileras se deben imprimir en pantalla. El programa tiene que seguir leyendo strings del usuario hasta que el usuario ingrese un string vacío (no digitando números, solamente la tecla "Enter".). Si el usuario ingresa una hilera que tenga un caracter no numérico, se le debe solicitar de nuevo ingresar la hilera hasta que ingrese una correcta.
#
# > Por ejemplo:
#
# ```markdown
# >>>
# Digite una tira de números: 098732978459287414578
# Los pares de esa tira son: 0 8 2 8 4 2 8 4 4 8
# Los impares de esa tira son: 9 7 3 9 7 5 9 7 1 5 7
#
# Digite una tira de números: 33333
# Los pares de esa tira son:
# Los impares de esa tira son: 3 3 3 3 3
#
# Digite una tira de números: 3434343434
# Los pares de esa tira son: 4 4 4 4 4
# Los impares de esa tira son: 3 3 3 3 3
#
# Digite una tira de números: (el usuario solamente digita Enter)
# >>>
# ```
#
# ---

# %%
# Acá su código

# %%
#@title Pruebas automáticas (solo ejecutar, no modificar)
from notebook_cell_tester.tester import ColabTestFramework, TestCase

# Inicializar el framework
tester = ColabTestFramework()

# Definir los casos de prueba
tests = [
    # ===== VALIDACIÓN DE ESTRUCTURA DEL CÓDIGO =====
    TestCase(
        name="Usa ciclo while para lectura continua",
        test_type="regex",
        pattern=r"while\s+",
        error_message="Debe usar un ciclo 'while' para seguir pidiendo hileras hasta que el usuario ingrese Enter"
    ),

    TestCase(
        name="No usa while True",
        test_type="not_regex",
        pattern=r"while\s*True\s*:",
        error_message="No debe usar un ciclo 'while' con la condición True para mostrar el menú repetidamente hasta que el usuario elija salir"
    ),

    TestCase(
        name="No usa break",
        test_type="not_regex",
        pattern=r"break",
        error_message="No debe usar un break para romper el ciclo"
    ),

    TestCase(
        name="Usa ciclo for para recorrer la hilera",
        test_type="regex",
        pattern=r"for\s+\w+\s+in\s+",
        error_message="Debe usar un ciclo 'for' para recorrer cada carácter de la hilera"
    ),

    TestCase(
        name="Usa input() para solicitar datos",
        test_type="regex",
        pattern=r"input\s*\(",
        error_message="Debe usar input() para solicitar la hilera de números al usuario"
    ),

    TestCase(
        name="Valida que la hilera sea numérica",
        test_type="regex",
        pattern=r"(isdigit|isnumeric|\d)",
        error_message="Debe validar que todos los caracteres de la hilera sean dígitos (usar .isdigit() o similar)"
    ),

    TestCase(
        name="Usa operador módulo % para determinar paridad",
        test_type="regex",
        pattern=r"%\s*2",
        error_message="Debe usar el operador módulo (%) para determinar si un número es par o impar"
    ),

    TestCase(
        name="Verifica si hilera está vacía",
        test_type="regex",
        pattern=r"(==\s*['\"][\s]*['\"]|len\s*\(\w+\)\s*==\s*0|not\s+\w+)",
        error_message="Debe verificar si la hilera está vacía para terminar el ciclo"
    ),

    TestCase(
        name="Imprime los números pares",
        test_type="regex",
        pattern=r"print\s*\(",
        error_message="Debe usar print() para mostrar los números pares e impares"
    ),

    TestCase(
        name="No asigna hileras de números directamente",
        test_type="not_regex",
        pattern=r"^\s*\w+\s*=\s*['\"][0-9]+['\"]",
        error_message="No debe asignar hileras de números directamente. Deben obtenerse del usuario con input()"
    ),

    # ===== CASOS DE PRUEBA FUNCIONALES =====
    TestCase(
        name="Caso 1: Hilera mixta larga",
        test_type="partial_output",
        stdin_input="098732978459287414578\n\n",
        expected="Los pares de esa tira son: 0 8 2 8 4 2 8 4 4 8\nLos impares de esa tira son: 9 7 3 9 7 5 9 7 1 5 7",
        similarity_threshold=0.7
    ),

    TestCase(
        name="Caso 2: Solo impares",
        test_type="partial_output",
        stdin_input="33333\n\n",
        expected="Los pares de esa tira son:\nLos impares de esa tira son: 3 3 3 3 3",
        similarity_threshold=0.7
    ),

    TestCase(
        name="Caso 3: Pares e impares alternados",
        test_type="partial_output",
        stdin_input="3434343434\n\n",
        expected="Los pares de esa tira son: 4 4 4 4 4\nLos impares de esa tira son: 3 3 3 3 3",
        similarity_threshold=0.7
    ),

    TestCase(
        name="Caso 4: Solo pares",
        test_type="partial_output",
        stdin_input="2468\n\n",
        expected="Los pares de esa tira son: 2 4 6 8\nLos impares de esa tira son:",
        similarity_threshold=0.7
    ),

    TestCase(
        name="Caso 5: Solo ceros (pares)",
        test_type="partial_output",
        stdin_input="0000\n\n",
        expected="Los pares de esa tira son: 0 0 0 0\nLos impares de esa tira son:",
        similarity_threshold=0.7
    ),

    TestCase(
        name="Caso 6: Un solo dígito par",
        test_type="partial_output",
        stdin_input="8\n\n",
        expected="Los pares de esa tira son: 8\nLos impares de esa tira son:",
        similarity_threshold=0.7
    ),

    TestCase(
        name="Caso 7: Un solo dígito impar",
        test_type="partial_output",
        stdin_input="7\n\n",
        expected="Los pares de esa tira son:\nLos impares de esa tira son: 7",
        similarity_threshold=0.7
    ),

    # ===== VALIDACIÓN DE ENTRADA INCORRECTA =====
    TestCase(
        name="Rechaza entrada con letras y vuelve a pedir",
        test_type="partial_output",
        stdin_input="abc123\n123\n\n",
        expected="Los pares de esa tira son: 2\nLos impares de esa tira son: 1 3",
        similarity_threshold=0.4
    ),

    TestCase(
        name="Rechaza entrada con espacios",
        test_type="partial_output",
        stdin_input="12 34\n1234\n\n",
        expected="Los pares de esa tira son: 2 4\nLos impares de esa tira son: 1 3",
        similarity_threshold=0.4
    ),

    TestCase(
        name="Rechaza entrada con caracteres especiales",
        test_type="partial_output",
        stdin_input="12@34\n1234\n\n",
        expected="Los pares de esa tira son: 2 4\nLos impares de esa tira son: 1 3",
        similarity_threshold=0.4,
    ),

    # ===== MÚLTIPLES ENTRADAS =====
    TestCase(
        name="Procesa múltiples hileras correctamente",
        test_type="partial_output",
        stdin_input="123\n456\n789\n\n",
        expected="Los pares de esa tira son: 2\nLos impares de esa tira son: 1 3\nLos pares de esa tira son: 4 6\nLos impares de esa tira son: 5\nLos pares de esa tira son: 8\nLos impares de esa tira son: 7 9",
        similarity_threshold=0.7
    ),

    # ===== CASOS EDGE =====
    TestCase(
        name="Termina con entrada vacía (solo Enter)",
        test_type="output",
        stdin_input="\n",
        expected=""
    ),
]

# Ejecutar las pruebas
tester.run_tests(tests)

# Mostrar resultados
tester.display_results()

# %% [markdown]
# ---
#
# **Ejercicio 3**
#
# Construya un programa que convierta grados Celsius a Fahrenheit y Fahrenheit a Celsius. Para ello, el programa presenta un menú con 3 opciones:
#
# - 1. Convierte de Celsius a Fahrenheit
# - 2. Convierte de Fahrenheit a Celsius
# - 3. Salir.
#
# Luego de seleccionar la opción 1 o 2, el usuario ingresa un valor en Celsius o en Fahrenheit, según
# corresponda, y el programa le devuelve el dato equivalente en la escala deseada. Este termina hasta que el usuario digita la opción 3.
#
# Tome en cuenta que las fórmulas para conversiones son:
#
# $$
# F = (\frac{9}{5} \cdot C) + 32
# $$
#
# $$
# C = \frac{5}{9} \cdot (F - 32)
# $$
#
# Ejemplo de salida:
# ```markdown
# >>>
# MENU
# ====================================
# 1. Convierte de Celsius a Fahrenheit
# 2. Convierte de Fahrenheit a Celsius
# 3. Salir.
# ====================================
# Seleccione una opción: 1
# Digite la cantidad de Celsius: 35
# Conversion: 95 F
#
# Seleccione una opción: ...
# >>>
# ```
#
# **NOTA**: Su programa debe ASEGURARSE de que se ingresen los tipos de datos correctos. Si el usuario ingresa un tipo de dato incorrecto, pídalo nuevamente HASTA que lo ingrese de forma correcta.
#
#
# ---

# %%
# Acá el código

# %%
#@title Pruebas automáticas (solo ejecutar, no modificar)
from notebook_cell_tester.tester import ColabTestFramework, TestCase

# Inicializar el framework
tester = ColabTestFramework()

# Definir los casos de prueba
tests = [
    # ===== VALIDACIÓN DE ESTRUCTURA DEL CÓDIGO =====
    TestCase(
        name="Usa ciclo while para el menú",
        test_type="regex",
        pattern=r"while\s+",
        error_message="Debe usar un ciclo 'while' para mostrar el menú repetidamente hasta que el usuario elija salir"
    ),

    # ===== VALIDACIÓN DE ESTRUCTURA DEL CÓDIGO =====
    TestCase(
        name="No usa while True",
        test_type="not_regex",
        pattern=r"while\s*True\s*:",
        error_message="No debe usar un ciclo 'while' con la condición True para mostrar el menú repetidamente hasta que el usuario elija salir"
    ),

    TestCase(
        name="No usa break",
        test_type="not_regex",
        pattern=r"break",
        error_message="No debe usar un break para romper el ciclo"
    ),

    TestCase(
        name="Muestra menú con las 3 opciones",
        test_type="regex",
        pattern=r"(MENU|Menú|menu)",
        error_message="Debe mostrar un menú con las opciones disponibles"
    ),

    TestCase(
        name="Usa input() para solicitar datos",
        test_type="regex",
        pattern=r"input\s*\(",
        error_message="Debe usar input() para solicitar la opción del menú y los valores de temperatura"
    ),

    TestCase(
        name="Usa if/elif/else o match para selección de menú",
        test_type="regex",
        pattern=r"(if|elif|match)\s+",
        error_message="Debe usar condicionales if/elif/else para manejar las diferentes opciones del menú"
    ),

    TestCase(
        name="Implementa conversión Celsius a Fahrenheit",
        test_type="regex",
        pattern=r"(\(9/5\)|9/5|1\.8).*\+.*32",
        error_message="Debe usar la fórmula correcta para convertir de Celsius a Fahrenheit: F = (9/5 * C) + 32"
    ),

    TestCase(
        name="Implementa conversión Fahrenheit a Celsius",
        test_type="regex",
        pattern=r"(5/9|0\.555|5\s*/\s*9).*(\-\s*32|32)",
        error_message="Debe usar la fórmula correcta para convertir de Fahrenheit a Celsius: C = 5/9 * (F - 32)"
    ),

    TestCase(
        name="No asigna valores de temperatura directamente",
        test_type="not_regex",
        pattern=r"^\s*(celsius|fahrenheit|temperatura|temp)\s*=\s*-?\d+\.?\d*\s*$",
        error_message="No debe asignar valores de temperatura directamente. Deben obtenerse del usuario con input()"
    ),

    TestCase(
        name="No asigna la opción del menú directamente",
        test_type="not_regex",
        pattern=r"^\s*opci[oó]n\s*=\s*[123]\s*$",
        error_message="No debe asignar la opción del menú directamente. Debe obtenerse del usuario con input()"
    ),

    # ===== CASOS DE PRUEBA: CELSIUS A FAHRENHEIT =====
    TestCase(
        name="Conversión C→F: 0°C = 32°F",
        test_type="regex_output",
        stdin_input="1\n0\n3\n",
        pattern="32"
    ),

    TestCase(
        name="Conversión C→F: 100°C = 212°F",
        test_type="regex_output",
        stdin_input="1\n100\n3\n",
        pattern="212"
    ),

    TestCase(
        name="Conversión C→F: 35°C = 95°F",
        test_type="regex_output",
        stdin_input="1\n35\n3\n",
        pattern="95"
    ),

    TestCase(
        name="Conversión C→F: -40°C = -40°F",
        test_type="regex_output",
        stdin_input="1\n-40\n3\n",
        pattern="-40"
    ),

    TestCase(
        name="Conversión C→F: 25°C = 77°F",
        test_type="regex_output",
        stdin_input="1\n25\n3\n",
        pattern="77"
    ),

    # ===== CASOS DE PRUEBA: FAHRENHEIT A CELSIUS =====
    TestCase(
        name="Conversión F→C: 32°F = 0°C",
        test_type="regex_output",
        stdin_input="2\n32\n3\n",
        pattern="0"
    ),

    TestCase(
        name="Conversión F→C: 212°F = 100°C",
        test_type="regex_output",
        stdin_input="2\n212\n3\n",
        pattern="100"
    ),

    TestCase(
        name="Conversión F→C: 95°F = 35°C",
        test_type="regex_output",
        stdin_input="2\n95\n3\n",
        pattern="35"
    ),

    TestCase(
        name="Conversión F→C: -40°F = -40°C",
        test_type="regex_output",
        stdin_input="2\n-40\n3\n",
        pattern="-40"
    ),

    TestCase(
        name="Conversión F→C: 77°F = 25°C",
        test_type="regex_output",
        stdin_input="2\n77\n3\n",
        pattern="25"
    ),

    # ===== MÚLTIPLES CONVERSIONES =====
    TestCase(
        name="Múltiples conversiones antes de salir",
        test_type="regex_output",
        stdin_input="1\n0\n2\n32\n1\n100\n3\n",
        pattern="32.*0.*212"
    ),

    TestCase(
        name="Alterna entre ambas conversiones",
        test_type="regex_output",
        stdin_input="1\n25\n2\n77\n1\n0\n2\n32\n3\n",
        pattern="77.*25.*32.*0"
    ),

    # ===== VALIDACIÓN DE ENTRADA INCORRECTA =====
    TestCase(
        name="Rechaza opción inválida y vuelve a pedir",
        test_type="regex_output",
        stdin_input="5\n1\n0\n3\n",
        pattern="32"
    ),

    TestCase(
        name="Rechaza texto en opción y vuelve a pedir",
        test_type="regex_output",
        stdin_input="abc\n1\n0\n3\n",
        pattern="32"
    ),

    TestCase(
        name="Rechaza texto en temperatura y vuelve a pedir",
        test_type="regex_output",
        stdin_input="1\nxyz\n100\n3\n",
        pattern="212"
    ),

    TestCase(
        name="Rechaza entrada vacía y vuelve a pedir",
        test_type="regex_output",
        stdin_input="\n1\n0\n3\n",
        pattern="32"
    ),

    # ===== CASO: SALIR INMEDIATAMENTE =====
    TestCase(
        name="Sale inmediatamente con opción 3",
        test_type="regex_output",
        stdin_input="3\n",
        pattern=""
    ),

    # ===== CASOS CON DECIMALES =====
    TestCase(
        name="Conversión C→F con decimales: 36.5°C",
        test_type="regex_output",
        pattern=r"97\.7",
        stdin_input="1\n36.5\n3\n",
    ),

    TestCase(
        name="Conversión F→C con decimales: 98.6°F",
        test_type="regex_output",
        stdin_input="2\n98.6\n3\n",
        pattern="37"
    ),
]

# Ejecutar las pruebas
tester.run_tests(tests)

# Mostrar resultados
tester.display_results()
