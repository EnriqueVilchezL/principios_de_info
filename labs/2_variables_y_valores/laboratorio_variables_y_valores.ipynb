# %% [markdown]
# # Principios de Informática: Laboratorio de Tipos de Datos y Variables en Python 🧮
# ### Las piezas fundamentales de cualquier programa
#
# **Curso:** Principios de Informática
#
# ---
#
# ## Instrucciones 🚧
#
# ### 1.	Objetivo
#   * El objetivo es que usted aplique los conceptos vistos en clase utilizando Python en un entorno interactivo.
#
# ### 2.	Ejecución
#   * Lea atentamente cada problema o ejercicio que se le plantee en las celdas de texto (Markdown).
#   * Escriba su código en las celdas de código justo debajo de cada enunciado.
#   * Ejecute cada celda para verificar que su código funcione correctamente.
#   * Puede añadir celdas adicionales si lo considera necesario para dividir el código o realizar pruebas.
#   * Se le recuerda que está **estrictamente prohibido** utilizar herramientas de inteligencia artificial para hacer sus soluciones. Puede ver cómo desactivar **Gemini** en Colab en este link: [![Desactivar Gemini](https://colab.research.google.com/assets/colab-badge.svg)](https://githubtocolab.com/EnriqueVilchezL/principios_de_info/blob/main/1_fundamentos_de_la_programacion/desactivar_gemini.ipynb).
#
# ### 3.	Documentación
#   * Si lo considera necesario, utilice celdas de texto (Markdown) para agregar comentarios, explicaciones o respuestas a preguntas.
#   * Preferiblemente agregue comentarios significativos que ilustren el proceso en el código para hacerlo más claro, usando `#` o `"""Comentatio acá"""` en sus celdas de código.
#   * Organice el notebook de manera clara con títulos, subtítulos y descripciones pertinentes.
#
# ### 4.	Entrega
#   * Guarde su notebook con el nombre `laboratorio_#_carne.ipynb`. Por ejemplo: `laboratorio_01_c18477.ipynb`.
#   * Descargue el archivo desde Colab (`Archivo` -> `Descargar` > `Descargar .ipynb`).
#   * Entregue el archivo `.ipynb`. Este laboratorio debe entregarse a través de Mediación Virtual.
#
# ### 5.	Recomendaciones
#   * Ponga comentarios en su código para facilitar su comprensión.
#   * Utilice nombres claros y significativos para variables y funciones.
#   * Verifique que todas las celdas se ejecuten sin errores.
#   * Mantenga el notebook organizado y bien documentado.
#   * No dude en consultar en caso de dudas o dificultades.
#
# ### 6.	Evaluación
#   * Se evaluará que el código funcione correctamente y resuelva los problemas planteados.
#   * Se tomará en cuenta la claridad en la documentación y la organización del notebook.
#   * Se tomará en cuenta la nomenclatura de variables y funciones creadas. Estos nombres **deben** ser significativos. Por ejemplo, en vez de nombrar una variable `a`, nombrela con algo que represente su significado, como `nombre`, `edad_de_persona`, etc. Esto se exceptúa en los ejercicios en donde el mismo enunciado nombra las variables que se deben usar.
#   * **Debe poder ejecutarse el notebook de forma secuencial y que funcione correctamente (no se aceptará la ejecución de celdas en desorden para obtener el resultado deseado).**
#   * Cada ejercicio debe resolverse de manera **independiente**. Puede usar los mismos nombres de variables o funciones en distintos ejercicios, pero los valores de las variables (o resultados previos) **no se pueden reutilizar entre ejercicios salvo que se indique lo contrario en el enunciado del ejercicio**.
#
# #### Ejemplo de independencia entre ejercicios
#
# Lo incorrecto 🚫:
#
# | Ejercicio | Código | Comentario |
# |------------|-----------|--------|
# | 1 | x = 10<br>y = 5<br>suma = x + y<br>print(suma) | Calcula la suma correctamente |
# | 2 | doble = suma * 2<br>print(doble) | Reutiliza 'suma' del ejercicio 1, lo cual **no está permitido** |
#
# Lo correcto ✅:
#
# | Ejercicio | Código | Comentario |
# |------------|-----------|--------|
# | 1 | x = 10<br>y = 5<br>suma = x + y<br>print(suma) | Calcula la suma correctamente |
# | 2 | suma = 7 + 3<br>doble = suma * 2<br>print(doble) | No eutiliza 'suma' del ejercicio 1. Cada ejercicio se resuelve de manera independiente |

# %% [markdown]
# # Pruebas automáticas
#
# **EJECUTE LA CELDA DE ABAJO ANTES DE EMPEZAR A EJECUTAR SU CÓDIGO**
# Esto sirve para que pueda ejecutar casos de prueba sobre su código.
#
# ---

# %%
# !pip install --upgrade --force-reinstall notebook-cell-tester --q

# %% [markdown]
# ---
#
# **Ejercicio 1**
#
# Revise e imprima el tipo de dato de cada uno de estos datos:
# ```python
# fuerza = "8.8"
# cantidad_de_bacterias = "90"
# son_nuevas_especies = 1
# marca_del_motor = 392019
# ```
#
# Use `type()` para ver los tipos e imprimirlos.
#
# Los valores correctos de cada variable deberían ser `fuerza` -> `float`, `cantidad_de_bacterias` -> `int`, `son_nuevas_especies` -> `bool` y `marca_del_motor` -> `str`. Realice una operación de `casting` para convertirlos a los tipos correctos. Imprima los nuevos tipos por medio de `type()`.
#
# Su programa debería imprimir exactamente lo siguiente:
# ```txt
# La variable "fuerza" original es 8.8, y su tipo es <class 'str'>
# La variable "cantidad_de_bacterias" original es 90, y su tipo es <class 'str'>
# La variable "son_nuevas_especies" original es 1, y su tipo es <class 'int'>
# La variable "marca_del_motor" original es 392019, y su tipo es <class 'int'>
#
# La variable "fuerza" modificada es 8.8, y su tipo es <class 'float'>
# La variable "cantidad_de_bacterias" modificada es 90, y su tipo es <class 'int'>
# La variable "son_nuevas_especies" modificada es True, y su tipo es <class 'bool'>
# La variable "marca_del_motor" modificada es 392019, y su tipo es <class 'str'>
# ```
#
# **Sugerencia**: Utilice las comillas simples (') para definir sus hileras para mostrar los mensajes. Esto permite utilizar el caracter de doble comillas (") como parte del mensaje. Por ejemplo, formatee sus mensajes haciendo el str con comillas simples, como `'La variable "fuerza" original es ...'`, en vez de hacer `"La variable "fuerza" original es ..."`, pues esto daría un conflicto con las comillas dobles en "fuerza".
#
# ---

# %%
# ====== NO MODIFICAR ESTE BLOQUE ======
fuerza = "8.8"
cantidad_de_bacterias = "90"
son_nuevas_especies = 1
marca_del_motor = 392019
# ====== NO MODIFICAR ESTE BLOQUE ======

# Acá su código

# Imprimir valores y tipos originales
print(f'La variable "fuerza" original es {fuerza}, y su tipo es {type(fuerza)}')
print(f'La variable "cantidad_de_bacterias" original es {cantidad_de_bacterias}, y su tipo es {type(cantidad_de_bacterias)}')
print(f'La variable "son_nuevas_especies" original es {son_nuevas_especies}, y su tipo es {type(son_nuevas_especies)}')
print(f'La variable "marca_del_motor" original es {marca_del_motor}, y su tipo es {type(marca_del_motor)}')

print()

# Casting a los tipos correctos
fuerza = float(fuerza)
cantidad_de_bacterias = int(cantidad_de_bacterias)
son_nuevas_especies = bool(son_nuevas_especies)
marca_del_motor = str(marca_del_motor)

# Imprimir valores y tipos modificados
print(f'La variable "fuerza" modificada es {fuerza}, y su tipo es {type(fuerza)}')
print(f'La variable "cantidad_de_bacterias" modificada es {cantidad_de_bacterias}, y su tipo es {type(cantidad_de_bacterias)}')
print(f'La variable "son_nuevas_especies" modificada es {son_nuevas_especies}, y su tipo es {type(son_nuevas_especies)}')
print(f'La variable "marca_del_motor" modificada es {marca_del_motor}, y su tipo es {type(marca_del_motor)}')
# Out:
# La variable "fuerza" original es 8.8, y su tipo es <class 'str'>
# La variable "cantidad_de_bacterias" original es 90, y su tipo es <class 'str'>
# La variable "son_nuevas_especies" original es 1, y su tipo es <class 'int'>
# La variable "marca_del_motor" original es 392019, y su tipo es <class 'int'>
#
# La variable "fuerza" modificada es 8.8, y su tipo es <class 'float'>
# La variable "cantidad_de_bacterias" modificada es 90, y su tipo es <class 'int'>
# La variable "son_nuevas_especies" modificada es True, y su tipo es <class 'bool'>
# La variable "marca_del_motor" modificada es 392019, y su tipo es <class 'str'>

# %%
#@title Pruebas automáticas (solo ejecutar, no modificar)
from notebook_cell_tester.tester import ColabTestFramework, TestCase, TestSection

tester = ColabTestFramework()

tests = [
    TestSection("Sección — Correctitud", [
        TestCase(
            name="Tipos originales impresos correctamente",
            test_type="multiline_output",
            expected=(
                "La variable \"fuerza\" original es 8.8, y su tipo es <class 'str'>" + "\n" +
                "La variable \"cantidad_de_bacterias\" original es 90, y su tipo es <class 'str'>" + "\n" +
                "La variable \"son_nuevas_especies\" original es 1, y su tipo es <class 'int'>" + "\n" +
                "La variable \"marca_del_motor\" original es 392019, y su tipo es <class 'int'>"
            ),
            success_message="Los tipos originales se imprimen correctamente",
            error_message="Algunos tipos originales no se imprimen correctamente. Asegúrese de imprimir el valor y el tipo de cada variable ANTES de hacer el casting, usando type(). Verifique el formato exacto del mensaje indicado en el enunciado.",
        ),
        TestCase(
            name="Tipos modificados impresos correctamente",
            test_type="multiline_output",
            expected=(
                "La variable \"fuerza\" modificada es 8.8, y su tipo es <class 'float'>" + "\n" +
                "La variable \"cantidad_de_bacterias\" modificada es 90, y su tipo es <class 'int'>" + "\n" +
                "La variable \"son_nuevas_especies\" modificada es True, y su tipo es <class 'bool'>" + "\n" +
                "La variable \"marca_del_motor\" modificada es 392019, y su tipo es <class 'str'>"
            ),
            success_message="Los tipos modificados se imprimen correctamente",
            error_message="Algunos tipos modificados no se imprimen correctamente. Realice el casting: fuerza→float(), cantidad_de_bacterias→int(), son_nuevas_especies→bool(), marca_del_motor→str(). Luego imprima el nuevo valor y su tipo con type().",
        ),
    ]),
    TestSection("Sección — Estructura del código", [
        TestCase(
            name="Se utiliza float() para la conversión de fuerza",
            test_type="regex",
            pattern=r"\bfloat\(",
            success_message="Se utiliza float() correctamente para la conversión de fuerza",
            error_message="No se detectó el uso de float() en el código. Use float() para convertir la variable 'fuerza' de str a float.",
        ),
        TestCase(
            name="Se utiliza int() para la conversión de cantidad_de_bacterias",
            test_type="regex",
            pattern=r"\bint\(",
            success_message="Se utiliza int() correctamente para la conversión de cantidad_de_bacterias",
            error_message="No se detectó el uso de int() en el código. Use int() para convertir la variable 'cantidad_de_bacterias' de str a int.",
        ),
        TestCase(
            name="Se utiliza bool() para la conversión de son_nuevas_especies",
            test_type="regex",
            pattern=r"\bbool\(",
            success_message="Se utiliza bool() correctamente para la conversión de son_nuevas_especies",
            error_message="No se detectó el uso de bool() en el código. Use bool() para convertir la variable 'son_nuevas_especies' de int a bool.",
        ),
        TestCase(
            name="Se utiliza str() para la conversión de marca_del_motor",
            test_type="regex",
            pattern=r"\bstr\(",
            success_message="Se utiliza str() correctamente para la conversión de marca_del_motor",
            error_message="No se detectó el uso de str() en el código. Use str() para convertir la variable 'marca_del_motor' de int a str.",
        ),
    ]),
]

tester.run_sections(tests)
tester.display_results()
# Out:
#         <style>
#             .test-results {
#                 font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif;
#                 border-collapse: collapse;
#                 width: 100%;
#                 box-shadow: 0 2px 8px rgba(0,0,0,0.1);
#                 margin: 12px 0 24px 0;
#             }
#             .test-results th {
#                 background: linear-gradient(135deg, #667eea 0%, #764ba2 100%);
#                 color: white;
#                 padding: 15px;
#                 text-align: left;
#                 font-weight: 600;
#                 font-size: 14px;
#             }
#             .test-results td {
#                 padding: 12px 15px;
#                 border-bottom: 1px solid #e0e0e0;
#                 font-size: 13px;
#                 vertical-align: top;
#             }
#             .test-results tr:hover {
#                 background-color: #f8f9fa;
#             }
#             .status-pass {
# ...

# %% [markdown]
# ---
#
# **Ejercicio 2**
#
# Escriba un programa en Python que haga lo siguiente:
#
# 1. Solicite al usuario su **nombre completo**.
# 2. Salude al usuario con un mensaje personalizado, por ejemplo: `¡Hola, [Nombre]! ¿Cómo estas?`.
# 3. Pregunte al usuario su **peso en kilogramos** y **altura en metros**.
# 4. Imprima este mensaje usando las variables correspondientes: `Ya veo, [Nombre]... Pesas [kilogramos] kg y mides [altura] m`.
#
# ---

# %%
# Acá su código

# %%
#@title Pruebas automáticas (solo ejecutar, no modificar)
from notebook_cell_tester.tester import ColabTestFramework, TestCase, TestSection

tester = ColabTestFramework()

tests = [
    TestSection("Sección 1 — Correctitud", [
        TestCase(
            name="El saludo incluye el nombre completo del usuario",
            test_type="regex_output",
            stdin_input="María García\n65\n1.60\n",
            pattern=r"(?i)hola.*María García",
            error_message="El saludo no incluye el nombre del usuario o no tiene el formato correcto. Asegúrese de leer el nombre con input() y usarlo dentro del mensaje de saludo.",
        ),
        TestCase(
            name="El segundo mensaje incluye el nombre del usuario",
            test_type="regex_output",
            stdin_input="María García\n65\n1.60\n",
            pattern=r"(?i)(ya veo|María García).*(ya veo|María García)",
            error_message="El segundo mensaje no incluye el nombre del usuario. El formato esperado es: 'Ya veo, [Nombre]... Pesas [peso] kg y mides [altura] m'.",
        ),
        TestCase(
            name="El segundo mensaje incluye el peso y la altura",
            test_type="regex_output",
            stdin_input="María García\n65\n1.60\n",
            pattern=r"65.*kg.*1\.6|1\.6.*m.*65",
            error_message="El mensaje con los datos físicos no es correcto. Verifique que el programa solicite el peso en kg y la altura en m, y los muestre usando las variables correspondientes.",
        ),
    ]),
]

tester.run_sections(tests)
tester.display_results()

# %% [markdown]
# ---
#
# **Ejercicio 3**
#
# Escriba un programa que solicite al usuario ingresar la cantidad de kilómetros recorridos por una motocicleta y la cantidad de litros de combustible que se queman por kilómetro. El programa debe calcular la cantidad total de litros de combustible que la motocicleta gastó, y mostrarlo en pantalla (muestre únicamente el número, sin mensajes adicionales).
#
# Por ejemplo:
#
# | Kilómetros | Litros por kilómetro | Litros gastados |
# |--------|-----------------|-------------------------------|
# | 20      |   3          | 60                          |
# | 87      | 1             | 87                          |
# | 24      | 10             | 240                           |
# | 2.4      | 12.1            | 29.04                           |
#
# Recordatorio: Use el operador `*` para hacer multiplicaciones entre números.
#
# ---

# %%
# Acá su código

# %%
#@title Pruebas automáticas (solo ejecutar, no modificar)
from notebook_cell_tester.tester import ColabTestFramework, TestCase, TestSection

tester = ColabTestFramework()

tests = [
    TestSection("Sección 1 — Correctitud", [
        TestCase(
            name="Cálculo correcto: 20 km × 3 L/km = 60",
            test_type="regex_output",
            stdin_input="20\n3\n",
            pattern=r"^60(\.0+)?\s*$",
            error_message="El resultado no es correcto para 20 km y 3 L/km. La respuesta esperada es 60. Recuerde leer ambas entradas con input(), convertirlas a número con float() o int(), y usar el operador * para multiplicar.",
        ),
        TestCase(
            name="Cálculo correcto: 87 km × 1 L/km = 87",
            test_type="regex_output",
            stdin_input="87\n1\n",
            pattern=r"^87(\.0+)?\s*$",
            error_message="El resultado no es correcto para 87 km y 1 L/km. La respuesta esperada es 87. Verifique que no agrega texto adicional en la salida (el enunciado pide imprimir únicamente el número).",
        ),
    ]),
    TestSection("Sección 2 — Casos extremos", [
        TestCase(
            name="Cálculo correcto con decimales: 2.4 km × 12.1 L/km = 29.04",
            test_type="regex_output",
            stdin_input="2.4\n12.1\n",
            pattern=r"29\.04",
            error_message="El resultado no es correcto para entradas decimales. Para 2.4 km y 12.1 L/km el resultado esperado es 29.04. Asegúrese de convertir las entradas con float() para que admita números con punto decimal.",
        ),
    ]),
]

tester.run_sections(tests)
tester.display_results()

# %% [markdown]
# ---
#
# **Ejercicio 4**
#
# Escriba un programa que solicite al usuario el ingreso de dos palabras, las cuales se guardarán en dos variables distintas. A continuación, invierta el orden de los caracteres de ambas palabras y luego concaténelas usando un espacio.
#
# Por ejemplo, su programa debería imprimir los siguiente si el usuario ingresa las cadenas `oma` y `ramargorp`:
#
# ```txt
# Cadena 1: oma
# Cadena 2: ramargorp
#
# Cadena 1 invertida: amo
# Cadena 2 invertida: programar
#
# Cadenas concatenadas: amo programar
# ```
#
# ---

# %%
# Acá su código

# %%
#@title Pruebas automáticas (solo ejecutar, no modificar)
from notebook_cell_tester.tester import ColabTestFramework, TestCase, TestSection

tester = ColabTestFramework()

tests = [
    TestSection("Sección 1 — Correctitud", [
        TestCase(
            name="Primera cadena invertida correctamente",
            test_type="regex_output",
            stdin_input="oma\nramargorp\n",
            pattern=r"Cadena 1 invertida:\s*amo",
            error_message="La primera cadena no se invierte correctamente. Para invertir una cadena use slicing con paso negativo: cadena[::-1].",
        ),
        TestCase(
            name="Segunda cadena invertida correctamente",
            test_type="regex_output",
            stdin_input="oma\nramargorp\n",
            pattern=r"Cadena 2 invertida:\s*programar",
            error_message="La segunda cadena no se invierte correctamente. Para invertir una cadena use slicing con paso negativo: cadena[::-1].",
        ),
        TestCase(
            name="Cadenas concatenadas con espacio entre ellas",
            test_type="regex_output",
            stdin_input="oma\nramargorp\n",
            pattern=r"Cadenas concatenadas:\s*amo programar",
            error_message="La concatenación de las cadenas invertidas no es correcta. Recuerde unir las dos cadenas invertidas con exactamente un espacio entre ellas.",
        ),
    ]),
    TestSection("Sección 2 — Casos extremos", [
        TestCase(
            name="Palabras de un solo carácter",
            test_type="regex_output",
            stdin_input="a\nb\n",
            pattern=r"Cadenas concatenadas:\s*a b",
            error_message="El programa no funciona correctamente con palabras de un solo carácter. Verifique que el algoritmo de inversión funcione para cadenas de cualquier longitud.",
        ),
        TestCase(
            name="Palabra que es palíndromo",
            test_type="regex_output",
            stdin_input="ana\noma\n",
            pattern=r"Cadenas concatenadas:\s*ana amo",
            error_message="El programa no funciona correctamente cuando una de las palabras es un palíndromo (se lee igual al revés). Verifique que siempre aplica la inversión, sin casos especiales.",
        ),
    ]),
]

tester.run_sections(tests)
tester.display_results()

# %% [markdown]
# ---
#
# **Ejercicio 5**
#
#
# Escriba un programa que le solicite al usuario ingresar una fecha formada por 8 números, donde los primeros dos representan el día, los siguientes dos el mes y los últimos cuatro el año (DDMMAAAA). Separe los valores en distintas variables (una para el día, otra para el mes y otra para el año). Muestre al usuario la fecha con el formato DD / MM / AAAA.
#
# Por ejemplo, si la entrada original es `21082025`, su programa debe imprimir `21 / 08 / 2025`.
#
# ---

# %%
# Acá su código

# %%
#@title Pruebas automáticas (solo ejecutar, no modificar)
from notebook_cell_tester.tester import ColabTestFramework, TestCase, TestSection

tester = ColabTestFramework()

tests = [
    TestSection("Sección 1 — Correctitud", [
        TestCase(
            name="Fecha formateada correctamente: 21082025 → 21 / 08 / 2025",
            test_type="regex_output",
            stdin_input="21082025\n",
            pattern=r"21\s*/\s*08\s*/\s*2025",
            error_message="La fecha no se muestra con el formato correcto. Para '21082025' el resultado esperado es '21 / 08 / 2025'. Use slicing para extraer cada parte: fecha[0:2] (día), fecha[2:4] (mes), fecha[4:8] (año).",
        ),
        TestCase(
            name="Fecha formateada correctamente: 15031999 → 15 / 03 / 1999",
            test_type="regex_output",
            stdin_input="15031999\n",
            pattern=r"15\s*/\s*03\s*/\s*1999",
            error_message="La fecha no se muestra con el formato correcto para '15031999'. El resultado esperado es '15 / 03 / 1999'. Verifique que los índices de slicing sean correctos para cada parte.",
        ),
    ]),
    TestSection("Sección 2 — Casos extremos", [
        TestCase(
            name="Ceros iniciales preservados: 01012000 → 01 / 01 / 2000",
            test_type="regex_output",
            stdin_input="01012000\n",
            pattern=r"01\s*/\s*01\s*/\s*2000",
            error_message="El programa no preserva los ceros iniciales en el día o el mes. Recuerde que trabaja con cadenas (str), no con números enteros, así que el cero inicial se conserva automáticamente al usar slicing.",
        ),
    ]),
    TestSection("Sección 4 — Estructura del código", [
        TestCase(
            name="Se usa slicing para separar las partes de la fecha",
            test_type="regex",
            pattern=r"\[.+:.+\]",
            error_message="No se detectó el uso de slicing en el código. Use el operador de slicing [] para extraer cada parte de la fecha, por ejemplo: fecha[0:2] para el día, fecha[2:4] para el mes, fecha[4:8] para el año.",
        ),
    ]),
]

tester.run_sections(tests)
tester.display_results()

# %% [markdown]
# ---
#
# **Ejercicio 6**
#
# En un sistema de monitoreo ambiental se utilizan cuatro sensores colocados en posiciones fijas: norte, este, sur y oeste, con lecturas almacenadas en las variables `N`, `E`, `S` y `O` respectivamente.
#
# Por razones operativas, se necesita rotar los valores de las lecturas de los sensores de modo que:
# * El valor del sensor norte (`N`) pase a la variable del sensor este (`E`),
# * El valor del sensor este (`E`) pase a la variable del sensor sur (`S`),
# * El valor del sensor sur (`S`) pase a la variable del sensor oeste (`O`),
# * El valor del sensor oeste (`O`) pase a la variable del sensor norte (`N`).
#
# Esto simula un giro horario de las lecturas del sistema.
#
# Requisitos del programa:
# * Dadas las variables `N`, `E`, `S` y `O` con sus valores iniciales, escriba un algoritmo que intercambie estos valores.
# * Solo puede utilizar el operador de asignación (=) para copiar valores entre variables.
# * Puede crear variables temporales auxiliares si lo necesita.
# * No está permitido asignar directamente valores constantes ni hacer la rotación manual, es decir, no se aceptan soluciones que reemplacen las variables con los valores finales sin usar asignaciones entre variables.
#
# Ejemplos:
#
# | Sensor | Lectura inicial | Lectura después de la rotación |
# |--------|-----------------|-------------------------------|
# | N      | 8.7             | 1.2                           |
# | E      | 2.5             | 8.7                           |
# | S      | 3.1             | 2.5                           |
# | O      | 1.2             | 3.1                           |
#
# ---

# %%
# ====== NO MODIFICAR ESTE BLOQUE ======
N = 8.7
E = 2.5
S = 3.1
O = 1.2
# ====== NO MODIFICAR ESTE BLOQUE ======

# Acá su código

# %%
#@title Pruebas automáticas (solo ejecutar, no modificar)
from notebook_cell_tester.tester import ColabTestFramework, TestCase, TestSection

tester = ColabTestFramework()

tests = [
    TestSection("Sección 4 — Estructura del código", [
        TestCase(
            name="No se asignan valores literales directamente a las variables de sensor",
            test_type="not_regex",
            pattern=r"\b(N|E|S|O)\b\s*=\s*\d",
            error_message="Se detectó una asignación directa de un valor numérico a una variable de sensor (N, E, S u O). El ejercicio requiere intercambiar los valores usando asignaciones entre variables (por ejemplo, 'N = O'), no asignando literales como 'N = 1.2'.",
        ),
    ]),
    TestSection("Sección 5 — Variables y estado", [
        TestCase(
            name="Variable N tiene el valor correcto tras la rotación (debe ser 1.2)",
            test_type="variable",
            variable_name="N",
            validator=lambda x: abs(x - 1.2) < 0.001,
            error_message="La variable N no tiene el valor correcto. Después de la rotación horaria, N debe tomar el valor de O (1.2). Recuerde el orden: N←O, E←N, S←E, O←S.",
        ),
        TestCase(
            name="Variable E tiene el valor correcto tras la rotación (debe ser 8.7)",
            test_type="variable",
            variable_name="E",
            validator=lambda x: abs(x - 8.7) < 0.001,
            error_message="La variable E no tiene el valor correcto. Después de la rotación horaria, E debe tomar el valor de N (8.7). Tenga cuidado con el orden de las asignaciones: si sobreescribe N antes de usarlo, el valor original se pierde. Use una variable temporal.",
        ),
        TestCase(
            name="Variable S tiene el valor correcto tras la rotación (debe ser 2.5)",
            test_type="variable",
            variable_name="S",
            validator=lambda x: abs(x - 2.5) < 0.001,
            error_message="La variable S no tiene el valor correcto. Después de la rotación horaria, S debe tomar el valor de E (2.5). Verifique el orden de sus asignaciones para no perder ningún valor intermedio.",
        ),
        TestCase(
            name="Variable O tiene el valor correcto tras la rotación (debe ser 3.1)",
            test_type="variable",
            variable_name="O",
            validator=lambda x: abs(x - 3.1) < 0.001,
            error_message="La variable O no tiene el valor correcto. Después de la rotación horaria, O debe tomar el valor de S (3.1). Verifique el orden de sus asignaciones para no perder ningún valor intermedio.",
        ),
    ]),
]

tester.run_sections(tests)
tester.display_results()
