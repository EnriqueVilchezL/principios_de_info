# %% [markdown]
# # Principios de Informática: Laboratorio de visualización de Datos 📊
# ### Convirtiendo números en historias visuales
#
# **Curso:** Principios de Informática
#
# ---
#
# ## Instrucciones 🚧
#
# ### 1.	Objetivo
#   * El objetivo es que usted aplique los conceptos vistos en clase utilizando Python en un entorno interactivo.
#
# ### 2.	Ejecución
#   * Lea atentamente cada problema o ejercicio que se le plantee en las celdas de texto (Markdown).
#   * Escriba su código en las celdas de código justo debajo de cada enunciado.
#   * Ejecute cada celda para verificar que su código funcione correctamente.
#   * Puede añadir celdas adicionales si lo considera necesario para dividir el código o realizar pruebas.
#   * Se le recuerda que está **estrictamente prohibido** utilizar herramientas de inteligencia artificial para hacer sus soluciones. Puede ver cómo desactivar **Gemini** en Colab en este link: [![Desactivar Gemini](https://colab.research.google.com/assets/colab-badge.svg)](https://githubtocolab.com/EnriqueVilchezL/principios_de_info/blob/main/1_fundamentos_de_la_programacion/desactivar_gemini.ipynb).
#
# ### 3.	Documentación
#   * Si lo considera necesario, utilice celdas de texto (Markdown) para agregar comentarios, explicaciones o respuestas a preguntas.
#   * Preferiblemente agregue comentarios significativos que ilustren el proceso en el código para hacerlo más claro, usando `#` o `"""Comentatio acá"""` en sus celdas de código.
#   * Organice el notebook de manera clara con títulos, subtítulos y descripciones pertinentes.
#
# ### 4.	Entrega
#   * Guarde su notebook con el nombre `laboratorio_#_carne.ipynb`. Por ejemplo: `laboratorio_01_c18477.ipynb`.
#   * Descargue el archivo desde Colab (`Archivo` -> `Descargar` > `Descargar .ipynb`).
#   * Entregue el archivo `.ipynb`. Este laboratorio debe entregarse a través de Mediación Virtual.
#
# ### 5.	Recomendaciones
#   * Ponga comentarios en su código para facilitar su comprensión.
#   * Utilice nombres claros y significativos para variables y funciones.
#   * Verifique que todas las celdas se ejecuten sin errores.
#   * Mantenga el notebook organizado y bien documentado.
#   * No dude en consultar en caso de dudas o dificultades.
#
# ### 6.	Evaluación
#   * Se evaluará que el código funcione correctamente y resuelva los problemas planteados.
#   * Se tomará en cuenta la claridad en la documentación y la organización del notebook.
#   * Se tomará en cuenta la nomenclatura de variables y funciones creadas. Estos nombres **deben** ser significativos. Por ejemplo, en vez de nombrar una variable `a`, nombrela con algo que represente su significado, como `nombre`, `edad_de_persona`, etc. Esto se exceptúa en los ejercicios en donde el mismo enunciado nombra las variables que se deben usar.
#   * **Debe poder ejecutarse el notebook de forma secuencial y que funcione correctamente (no se aceptará la ejecución de celdas en desorden para obtener el resultado deseado).**
#   * Cada ejercicio debe resolverse de manera **independiente**. Puede usar los mismos nombres de variables o funciones en distintos ejercicios, pero los valores de las variables (o resultados previos) **no se pueden reutilizar entre ejercicios salvo que se indique lo contrario en el enunciado del ejercicio**.
#
# #### Ejemplo de independencia entre ejercicios
#
# Lo incorrecto 🚫:
#
# | Ejercicio | Código | Comentario |
# |------------|-----------|--------|
# | 1 | x = 10<br>y = 5<br>suma = x + y<br>print(suma) | Calcula la suma correctamente |
# | 2 | doble = suma * 2<br>print(doble) | Reutiliza 'suma' del ejercicio 1, lo cual **no está permitido** |
#
# Lo correcto ✅:
#
# | Ejercicio | Código | Comentario |
# |------------|-----------|--------|
# | 1 | x = 10<br>y = 5<br>suma = x + y<br>print(suma) | Calcula la suma correctamente |
# | 2 | suma = 7 + 3<br>doble = suma * 2<br>print(doble) | No eutiliza 'suma' del ejercicio 1. Cada ejercicio se resuelve de manera independiente |

# %% [markdown]
# ## Pruebas automáticas 🧪
#
# Ejecute la siguiente celda para instalar la biblioteca de pruebas y luego ejecute cada celda de pruebas para verificar su solución.

# %%
# !pip install --upgrade notebook-cell-tester --q

# %% [markdown]
# **Ejercicio 1**
#
# En este ejercicio se va a trabajar con el conjunto de datos de `Spotify`. El conjunto de datos contiene información detallada sobre pistas musicales populares, incluyendo detalles de la canción, la fecha de su lanzamiento, su presencia en listas de reproducción y rankings de las principales plataformas de streaming, así como varias características acústicas.
#
# Realice lo siguiente con el conjunto de datos:
#
# 1. Cargue el `DataFrame` a una variable llamada `df`.
# 2. Muestre en pantalla las primeras 5 filas del `DataFrame`.
# 3.  Utilice el siguiente código, que sirve para convertir la columna streams a datos numéricos: `df['streams'] = pd.to_numeric(df['streams'], errors='coerce')`. El parámetro `errors` indica que para los datos en los que haya un error para convertirlo a un número, se van a poner como datos nulos.
# 4. Muestre la información de la columnas usando `.info()`.
# 5. Para las columnas que tengan menos de 953 **datos no nulos**, limpie los datos con alguno de los métodos vistos en clase, dependiendo de si los datos de la columna son numéricos o categóricos.
# 6. Guarde el nuevo `DataFrame` a un archivo `.csv` con nombre `spotify-clean.csv`.
#
# ---

# %%
# Acá su código

# %%
#@title Pruebas automáticas (solo ejecutar, no modificar)
from notebook_cell_tester.tester import ColabTestFramework, TestCase, TestSection

tester = ColabTestFramework()

tests = [
    TestSection("Sección 1 — Correctitud", [
        TestCase(
            name="df es un DataFrame de pandas",
            test_type="variable",
            variable_name="df",
            validator=lambda v: type(v).__name__ == "DataFrame",
            error_message="La variable `df` no es un DataFrame de pandas. Cargue el archivo CSV con `pd.read_csv()` y asigne el resultado a la variable `df`."
        ),
        TestCase(
            name="La columna 'streams' es de tipo numérico",
            test_type="variable",
            variable_name="df",
            validator=lambda v: hasattr(v, "dtypes") and "streams" in v.columns and str(v["streams"].dtype) in ["float64", "int64"],
            error_message="La columna 'streams' no es numérica. Aplique `pd.to_numeric(df['streams'], errors='coerce')` y asigne el resultado de vuelta a `df['streams']`."
        ),
        TestCase(
            name="Ninguna columna tiene menos de 953 valores no nulos tras la limpieza",
            test_type="variable",
            variable_name="df",
            validator=lambda v: hasattr(v, "columns") and all(v[col].notna().sum() >= 953 for col in v.columns),
            error_message="Hay columnas con menos de 953 valores no nulos. Limpie los datos nulos: use `fillna()` con la mediana o media para columnas numéricas, y con la moda para columnas categóricas."
        ),
    ]),
    TestSection("Sección 4 — Estructura del código", [
        TestCase(
            name="No usa 'while True'",
            test_type="not_regex",
            pattern=r"while\s+True",
            error_message="El código no debe usar `while True`. En este ejercicio no son necesarios bucles indefinidos."
        ),
        TestCase(
            name="No usa 'break'",
            test_type="not_regex",
            pattern=r"\bbreak\b",
            error_message="El código no debe usar `break`. Evite interrumpir el flujo de los bucles con esta instrucción."
        ),
        TestCase(
            name="Tiene una función 'main'",
            test_type="regex",
            pattern=r"def\s+main\s*\(",
            error_message="El código debe tener una función `main`. Organice el código principal dentro de `def main():` y llámela al final con `main()`."
        ),
        TestCase(
            name="Carga el archivo con read_csv",
            test_type="regex",
            pattern=r"read_csv\s*\(",
            error_message="No se detectó el uso de `pd.read_csv()`. Cargue el conjunto de datos de Spotify usando esta función."
        ),
        TestCase(
            name="Convierte la columna 'streams' a numérico con to_numeric",
            test_type="regex",
            pattern=r"to_numeric\s*\(",
            error_message="No se detectó el uso de `pd.to_numeric()`. Aplique `pd.to_numeric(df['streams'], errors='coerce')` tal como indica el enunciado."
        ),
        TestCase(
            name="Limpia datos nulos con fillna o dropna",
            test_type="regex",
            pattern=r"(fillna|dropna)\s*\(",
            error_message="No se detectó el uso de `fillna()` o `dropna()`. Limpie las columnas con datos nulos según su tipo: numérico → mediana/media, categórico → moda o eliminación."
        ),
        TestCase(
            name="Guarda el DataFrame limpio en 'spotify-clean.csv'",
            test_type="regex",
            pattern=r"to_csv\s*\(.*spotify-clean\.csv",
            error_message="No se detectó el guardado del DataFrame en 'spotify-clean.csv'. Use `df.to_csv('spotify-clean.csv')` para guardar el resultado de la limpieza."
        ),
    ]),
    TestSection("Sección 5 — Variables y estado", [
        TestCase(
            name="df contiene columnas clave del dataset de Spotify",
            test_type="variable",
            variable_name="df",
            validator=lambda v: hasattr(v, "columns") and all(c in v.columns for c in ["streams", "artist_count", "bpm"]),
            error_message="El DataFrame `df` no tiene las columnas esperadas del dataset de Spotify ('streams', 'artist_count', 'bpm'). Verifique que está cargando el archivo correcto y que no eliminó columnas necesarias."
        ),
    ]),
]

tester.run_sections(tests)
tester.display_results()

# %% [markdown]
# **Ejercicio 1.1 (Continuación)**
#
# Vamos a hacer algunas visualizaciones con este conjunto de datos. Para ello, realice y muestre las visualizaciones solicitadas en cada celda.
#
# Para gráfico o subgráfico solicitado debe tener los siguientes datos:
#
# - El gráfico como tal.
# - Título.
# - Etiquetas de los ejes `x` y `y`.
# - Leyenda (*si lo requiere*).
# - Cuadrícula (*grid*).
# - Color
#
# ---

# %% [markdown]
# Cree y muestre un histograma que muestre la distribución de la cantidad de artistas (*artist_count*) en las canciones.

# %%
# Acá su código

# %%
#@title Pruebas automáticas (solo ejecutar, no modificar)
from notebook_cell_tester.tester import ColabTestFramework, TestCase, TestSection

tester = ColabTestFramework()

tests = [
    TestSection("Sección 1 — Correctitud", [
        TestCase(
            name="El histograma usa la columna 'artist_count'",
            test_type="regex",
            pattern=r"artist_count",
            error_message="El gráfico no usa la columna 'artist_count'. El histograma debe mostrar la distribución de la cantidad de artistas por canción."
        ),
        TestCase(
            name="Se crea un histograma",
            test_type="regex",
            pattern=r"(plt\.hist\s*\(|\.hist\s*\(|kind\s*=\s*['\"]hist['\"])",
            error_message="No se detectó la creación de un histograma. Use `plt.hist()`, `df['artist_count'].hist()` o `df.plot(kind='hist')` para crear el gráfico."
        ),
    ]),
    TestSection("Sección 4 — Estructura del código", [
        TestCase(
            name="No usa 'while True'",
            test_type="not_regex",
            pattern=r"while\s+True",
            error_message="El código no debe usar `while True`. En este ejercicio no son necesarios bucles indefinidos."
        ),
        TestCase(
            name="No usa 'break'",
            test_type="not_regex",
            pattern=r"\bbreak\b",
            error_message="El código no debe usar `break`. Evite interrumpir el flujo de los bucles con esta instrucción."
        ),
        TestCase(
            name="Tiene una función 'main'",
            test_type="regex",
            pattern=r"def\s+main\s*\(",
            error_message="El código debe tener una función `main`. Organice el código del gráfico dentro de `def main():` y llámela al final."
        ),
        TestCase(
            name="El gráfico tiene título",
            test_type="regex",
            pattern=r"(plt\.title\s*\(|\.set_title\s*\()",
            error_message="El gráfico no tiene título. Use `plt.title('...')` o `ax.set_title('...')` para agregar un título descriptivo."
        ),
        TestCase(
            name="El gráfico tiene etiqueta en el eje X",
            test_type="regex",
            pattern=r"(plt\.xlabel\s*\(|\.set_xlabel\s*\()",
            error_message="El gráfico no tiene etiqueta en el eje X. Use `plt.xlabel('...')` o `ax.set_xlabel('...')` para describir el eje."
        ),
        TestCase(
            name="El gráfico tiene etiqueta en el eje Y",
            test_type="regex",
            pattern=r"(plt\.ylabel\s*\(|\.set_ylabel\s*\()",
            error_message="El gráfico no tiene etiqueta en el eje Y. Use `plt.ylabel('...')` o `ax.set_ylabel('...')` para describir el eje."
        ),
        TestCase(
            name="El gráfico tiene cuadrícula (grid)",
            test_type="regex",
            pattern=r"(plt\.grid\s*\(|\.grid\s*\()",
            error_message="El gráfico no tiene cuadrícula. Use `plt.grid(True)` o `ax.grid(True)` para activarla."
        ),
        TestCase(
            name="El gráfico tiene color especificado",
            test_type="regex",
            pattern=r"color\s*=",
            error_message="El gráfico no tiene un color especificado. Use el parámetro `color='...'` en la función de graficación para personalizar el color."
        ),
    ]),
]

tester.run_sections(tests)
tester.display_results()

# %% [markdown]
# Cree y muestre un gráfico de barras que muestre a las 5 canciones con más reproducciones (*streams*). Para esto, ordene el `df` por los *streams*.

# %%
# Acá su código

# %%
#@title Pruebas automáticas (solo ejecutar, no modificar)
from notebook_cell_tester.tester import ColabTestFramework, TestCase, TestSection

tester = ColabTestFramework()

tests = [
    TestSection("Sección 1 — Correctitud", [
        TestCase(
            name="El gráfico usa la columna 'streams'",
            test_type="regex",
            pattern=r"streams",
            error_message="El gráfico no usa la columna 'streams'. El gráfico de barras debe mostrar las canciones con más reproducciones en dicha columna."
        ),
        TestCase(
            name="Se crea un gráfico de barras",
            test_type="regex",
            pattern=r"(plt\.bar\s*\(|plt\.barh\s*\(|\.bar\s*\(|\.barh\s*\(|kind\s*=\s*['\"]bar['\"]|kind\s*=\s*['\"]barh['\"])",
            error_message="No se detectó la creación de un gráfico de barras. Use `plt.bar()`, `plt.barh()` o `df.plot(kind='bar')` para visualizar las canciones."
        ),
        TestCase(
            name="Los datos se ordenan por 'streams' antes de graficar",
            test_type="regex",
            pattern=r"sort_values\s*\(",
            error_message="No se detectó el uso de `sort_values()`. Ordene el DataFrame por la columna 'streams' antes de seleccionar las 5 canciones con más reproducciones."
        ),
        TestCase(
            name="Se seleccionan las 5 canciones top",
            test_type="regex",
            pattern=r"(\.head\s*\(\s*5\s*\)|\.tail\s*\(\s*5\s*\)|\[:5\]|\[-5:\])",
            error_message="No se detectó la selección de las 5 canciones top. Use `.head(5)` o `.tail(5)` después de ordenar según el sentido del sorting (ascendente o descendente)."
        ),
    ]),
    TestSection("Sección 4 — Estructura del código", [
        TestCase(
            name="No usa 'while True'",
            test_type="not_regex",
            pattern=r"while\s+True",
            error_message="El código no debe usar `while True`. En este ejercicio no son necesarios bucles indefinidos."
        ),
        TestCase(
            name="No usa 'break'",
            test_type="not_regex",
            pattern=r"\bbreak\b",
            error_message="El código no debe usar `break`. Evite interrumpir el flujo de los bucles con esta instrucción."
        ),
        TestCase(
            name="Tiene una función 'main'",
            test_type="regex",
            pattern=r"def\s+main\s*\(",
            error_message="El código debe tener una función `main`. Organice el código del gráfico dentro de `def main():` y llámela al final."
        ),
        TestCase(
            name="El gráfico tiene título",
            test_type="regex",
            pattern=r"(plt\.title\s*\(|\.set_title\s*\()",
            error_message="El gráfico no tiene título. Use `plt.title('...')` o `ax.set_title('...')` para agregar un título descriptivo."
        ),
        TestCase(
            name="El gráfico tiene etiqueta en el eje X",
            test_type="regex",
            pattern=r"(plt\.xlabel\s*\(|\.set_xlabel\s*\()",
            error_message="El gráfico no tiene etiqueta en el eje X. Use `plt.xlabel('...')` o `ax.set_xlabel('...')` para describir el eje."
        ),
        TestCase(
            name="El gráfico tiene etiqueta en el eje Y",
            test_type="regex",
            pattern=r"(plt\.ylabel\s*\(|\.set_ylabel\s*\()",
            error_message="El gráfico no tiene etiqueta en el eje Y. Use `plt.ylabel('...')` o `ax.set_ylabel('...')` para describir el eje."
        ),
        TestCase(
            name="El gráfico tiene cuadrícula (grid)",
            test_type="regex",
            pattern=r"(plt\.grid\s*\(|\.grid\s*\()",
            error_message="El gráfico no tiene cuadrícula. Use `plt.grid(True)` o `ax.grid(True)` para activarla."
        ),
        TestCase(
            name="El gráfico tiene color especificado",
            test_type="regex",
            pattern=r"color\s*=",
            error_message="El gráfico no tiene un color especificado. Use el parámetro `color='...'` en la función de graficación para personalizar el color."
        ),
    ]),
]

tester.run_sections(tests)
tester.display_results()

# %% [markdown]
# Cree y muestre un gráfico de líneas que muestre la relación entre la cantidad de reproducciones (*streams*) con respecto a la cantidad de listas de reproducción que contienen a la canción (*in_spotify_playlists*). Para esto, ordene el `df` por los *streams*.

# %%
# Acá su código

# %%
#@title Pruebas automáticas (solo ejecutar, no modificar)
from notebook_cell_tester.tester import ColabTestFramework, TestCase, TestSection

tester = ColabTestFramework()

tests = [
    TestSection("Sección 1 — Correctitud", [
        TestCase(
            name="El gráfico usa la columna 'streams'",
            test_type="regex",
            pattern=r"streams",
            error_message="El gráfico no usa la columna 'streams'. Esta columna debe ir en uno de los ejes del gráfico de líneas."
        ),
        TestCase(
            name="El gráfico usa la columna 'in_spotify_playlists'",
            test_type="regex",
            pattern=r"in_spotify_playlists",
            error_message="El gráfico no usa la columna 'in_spotify_playlists'. Use esta columna para representar la cantidad de listas de reproducción en el otro eje."
        ),
        TestCase(
            name="Se crea un gráfico de líneas",
            test_type="regex",
            pattern=r"(plt\.plot\s*\(|\.plot\s*\(|kind\s*=\s*['\"]line['\"])",
            error_message="No se detectó la creación de un gráfico de líneas. Use `plt.plot()` o `df.plot(kind='line')` para visualizar la relación."
        ),
        TestCase(
            name="Los datos se ordenan por 'streams' antes de graficar",
            test_type="regex",
            pattern=r"sort_values\s*\(",
            error_message="No se detectó el uso de `sort_values()`. Ordene el DataFrame por la columna 'streams' antes de crear el gráfico de líneas para que la tendencia sea visible."
        ),
    ]),
    TestSection("Sección 4 — Estructura del código", [
        TestCase(
            name="No usa 'while True'",
            test_type="not_regex",
            pattern=r"while\s+True",
            error_message="El código no debe usar `while True`. En este ejercicio no son necesarios bucles indefinidos."
        ),
        TestCase(
            name="No usa 'break'",
            test_type="not_regex",
            pattern=r"\bbreak\b",
            error_message="El código no debe usar `break`. Evite interrumpir el flujo de los bucles con esta instrucción."
        ),
        TestCase(
            name="Tiene una función 'main'",
            test_type="regex",
            pattern=r"def\s+main\s*\(",
            error_message="El código debe tener una función `main`. Organice el código del gráfico dentro de `def main():` y llámela al final."
        ),
        TestCase(
            name="El gráfico tiene título",
            test_type="regex",
            pattern=r"(plt\.title\s*\(|\.set_title\s*\()",
            error_message="El gráfico no tiene título. Use `plt.title('...')` o `ax.set_title('...')` para agregar un título descriptivo."
        ),
        TestCase(
            name="El gráfico tiene etiqueta en el eje X",
            test_type="regex",
            pattern=r"(plt\.xlabel\s*\(|\.set_xlabel\s*\()",
            error_message="El gráfico no tiene etiqueta en el eje X. Use `plt.xlabel('...')` o `ax.set_xlabel('...')` para describir el eje."
        ),
        TestCase(
            name="El gráfico tiene etiqueta en el eje Y",
            test_type="regex",
            pattern=r"(plt\.ylabel\s*\(|\.set_ylabel\s*\()",
            error_message="El gráfico no tiene etiqueta en el eje Y. Use `plt.ylabel('...')` o `ax.set_ylabel('...')` para describir el eje."
        ),
        TestCase(
            name="El gráfico tiene cuadrícula (grid)",
            test_type="regex",
            pattern=r"(plt\.grid\s*\(|\.grid\s*\()",
            error_message="El gráfico no tiene cuadrícula. Use `plt.grid(True)` o `ax.grid(True)` para activarla."
        ),
        TestCase(
            name="El gráfico tiene color especificado",
            test_type="regex",
            pattern=r"color\s*=",
            error_message="El gráfico no tiene un color especificado. Use el parámetro `color='...'` en la función de graficación para personalizar el color."
        ),
    ]),
]

tester.run_sections(tests)
tester.display_results()

# %% [markdown]
# Cree y muestre un gráfico de dispersión que muestre la relación entre el porcentaje de bailabilidad (*danceability_%*) y los latidos por minuto (*bpm*).

# %%
# Acá su código

# %%
#@title Pruebas automáticas (solo ejecutar, no modificar)
from notebook_cell_tester.tester import ColabTestFramework, TestCase, TestSection

tester = ColabTestFramework()

tests = [
    TestSection("Sección 1 — Correctitud", [
        TestCase(
            name="El gráfico usa la columna 'danceability_%'",
            test_type="regex",
            pattern=r"danceability",
            error_message="El gráfico no usa la columna 'danceability_%'. Esta columna debe estar en uno de los ejes del gráfico de dispersión."
        ),
        TestCase(
            name="El gráfico usa la columna 'bpm'",
            test_type="regex",
            pattern=r"\bbpm\b",
            error_message="El gráfico no usa la columna 'bpm'. Esta columna debe estar en el otro eje del gráfico de dispersión."
        ),
        TestCase(
            name="Se crea un gráfico de dispersión",
            test_type="regex",
            pattern=r"(plt\.scatter\s*\(|\.scatter\s*\(|kind\s*=\s*['\"]scatter['\"])",
            error_message="No se detectó la creación de un gráfico de dispersión. Use `plt.scatter()` o `df.plot(kind='scatter')` para visualizar la relación entre las dos variables."
        ),
    ]),
    TestSection("Sección 4 — Estructura del código", [
        TestCase(
            name="No usa 'while True'",
            test_type="not_regex",
            pattern=r"while\s+True",
            error_message="El código no debe usar `while True`. En este ejercicio no son necesarios bucles indefinidos."
        ),
        TestCase(
            name="No usa 'break'",
            test_type="not_regex",
            pattern=r"\bbreak\b",
            error_message="El código no debe usar `break`. Evite interrumpir el flujo de los bucles con esta instrucción."
        ),
        TestCase(
            name="Tiene una función 'main'",
            test_type="regex",
            pattern=r"def\s+main\s*\(",
            error_message="El código debe tener una función `main`. Organice el código del gráfico dentro de `def main():` y llámela al final."
        ),
        TestCase(
            name="El gráfico tiene título",
            test_type="regex",
            pattern=r"(plt\.title\s*\(|\.set_title\s*\()",
            error_message="El gráfico no tiene título. Use `plt.title('...')` o `ax.set_title('...')` para agregar un título descriptivo."
        ),
        TestCase(
            name="El gráfico tiene etiqueta en el eje X",
            test_type="regex",
            pattern=r"(plt\.xlabel\s*\(|\.set_xlabel\s*\()",
            error_message="El gráfico no tiene etiqueta en el eje X. Use `plt.xlabel('...')` o `ax.set_xlabel('...')` para describir el eje."
        ),
        TestCase(
            name="El gráfico tiene etiqueta en el eje Y",
            test_type="regex",
            pattern=r"(plt\.ylabel\s*\(|\.set_ylabel\s*\()",
            error_message="El gráfico no tiene etiqueta en el eje Y. Use `plt.ylabel('...')` o `ax.set_ylabel('...')` para describir el eje."
        ),
        TestCase(
            name="El gráfico tiene cuadrícula (grid)",
            test_type="regex",
            pattern=r"(plt\.grid\s*\(|\.grid\s*\()",
            error_message="El gráfico no tiene cuadrícula. Use `plt.grid(True)` o `ax.grid(True)` para activarla."
        ),
        TestCase(
            name="El gráfico tiene color especificado",
            test_type="regex",
            pattern=r"color\s*=",
            error_message="El gráfico no tiene un color especificado. Use el parámetro `color='...'` en `plt.scatter()` para personalizar el color."
        ),
    ]),
]

tester.run_sections(tests)
tester.display_results()

# %% [markdown]
# Cree y muestre el gráfico más adecuado para responder a la siguiente pregunta: ¿Existe una diferencia significativa en el rendimiento de reproducciones (*stream*) entre las canciones con un solo artista (*artist_count* = 1) y las colaboraciones (*artist_count* > 1)?

# %%
# Acá su código

# %%
#@title Pruebas automáticas (solo ejecutar, no modificar)
from notebook_cell_tester.tester import ColabTestFramework, TestCase, TestSection

tester = ColabTestFramework()

tests = [
    TestSection("Sección 1 — Correctitud", [
        TestCase(
            name="El gráfico usa la columna 'streams'",
            test_type="regex",
            pattern=r"streams",
            error_message="El gráfico no usa la columna 'streams'. Esta columna contiene las reproducciones que se quieren comparar entre artistas solos y colaboraciones."
        ),
        TestCase(
            name="El gráfico segmenta por 'artist_count'",
            test_type="regex",
            pattern=r"artist_count",
            error_message="El gráfico no usa la columna 'artist_count'. Use esta columna para separar canciones de un solo artista (artist_count == 1) de las colaboraciones (artist_count > 1)."
        ),
    ]),
    TestSection("Sección 4 — Estructura del código", [
        TestCase(
            name="No usa 'while True'",
            test_type="not_regex",
            pattern=r"while\s+True",
            error_message="El código no debe usar `while True`. En este ejercicio no son necesarios bucles indefinidos."
        ),
        TestCase(
            name="No usa 'break'",
            test_type="not_regex",
            pattern=r"\bbreak\b",
            error_message="El código no debe usar `break`. Evite interrumpir el flujo de los bucles con esta instrucción."
        ),
        TestCase(
            name="Tiene una función 'main'",
            test_type="regex",
            pattern=r"def\s+main\s*\(",
            error_message="El código debe tener una función `main`. Organice el código del gráfico dentro de `def main():` y llámela al final."
        ),
        TestCase(
            name="El gráfico tiene título",
            test_type="regex",
            pattern=r"(plt\.title\s*\(|\.set_title\s*\()",
            error_message="El gráfico no tiene título. Use `plt.title('...')` o `ax.set_title('...')` para agregar un título descriptivo."
        ),
        TestCase(
            name="El gráfico tiene etiqueta en el eje X",
            test_type="regex",
            pattern=r"(plt\.xlabel\s*\(|\.set_xlabel\s*\()",
            error_message="El gráfico no tiene etiqueta en el eje X. Use `plt.xlabel('...')` o `ax.set_xlabel('...')` para describir el eje."
        ),
        TestCase(
            name="El gráfico tiene etiqueta en el eje Y",
            test_type="regex",
            pattern=r"(plt\.ylabel\s*\(|\.set_ylabel\s*\()",
            error_message="El gráfico no tiene etiqueta en el eje Y. Use `plt.ylabel('...')` o `ax.set_ylabel('...')` para describir el eje."
        ),
        TestCase(
            name="El gráfico tiene cuadrícula (grid)",
            test_type="regex",
            pattern=r"(plt\.grid\s*\(|\.grid\s*\()",
            error_message="El gráfico no tiene cuadrícula. Use `plt.grid(True)` o `ax.grid(True)` para activarla."
        ),
        TestCase(
            name="El gráfico tiene color especificado",
            test_type="regex",
            pattern=r"color\s*=",
            error_message="El gráfico no tiene un color especificado. Use el parámetro `color='...'` en la función de graficación para personalizar el color."
        ),
    ]),
]

tester.run_sections(tests)
tester.display_results()
