# %% [markdown]
# # Principios de Informática: Laboratorio de Entrada y Salida de Datos ⌨️
# ### Del Teclado a la Pantalla: Hagamos que los programas hablen
#
# **Curso:** Principios de Informática
#
# ---
#
# ## Instrucciones 🚧
#
# ### 1.	Objetivo
#   * El objetivo es que usted aplique los conceptos vistos en clase utilizando Python en un entorno interactivo.
#
# ### 2.	Ejecución
#   * Lea atentamente cada problema o ejercicio que se le plantee en las celdas de texto (Markdown).
#   * Escriba su código en las celdas de código justo debajo de cada enunciado.
#   * Ejecute cada celda para verificar que su código funcione correctamente.
#   * Puede añadir celdas adicionales si lo considera necesario para dividir el código o realizar pruebas.
#   * Se le recuerda que está **estrictamente prohibido** utilizar herramientas de inteligencia artificial para hacer sus soluciones. Puede ver cómo desactivar **Gemini** en Colab en este link: [![Desactivar Gemini](https://colab.research.google.com/assets/colab-badge.svg)](https://githubtocolab.com/EnriqueVilchezL/principios_de_info/blob/main/1_fundamentos_de_la_programacion/desactivar_gemini.ipynb).
#
# ### 3.	Documentación
#   * Si lo considera necesario, utilice celdas de texto (Markdown) para agregar comentarios, explicaciones o respuestas a preguntas.
#   * Preferiblemente agregue comentarios significativos que ilustren el proceso en el código para hacerlo más claro, usando `#` o `"""Comentatio acá"""` en sus celdas de código.
#   * Organice el notebook de manera clara con títulos, subtítulos y descripciones pertinentes.
#
# ### 4.	Entrega
#   * Guarde su notebook con el nombre `laboratorio_#_carne.ipynb`. Por ejemplo: `laboratorio_01_c18477.ipynb`.
#   * Descargue el archivo desde Colab (`Archivo` -> `Descargar` > `Descargar .ipynb`).
#   * Entregue el archivo `.ipynb`. Este laboratorio debe entregarse a través de Mediación Virtual.
#
# ### 5.	Recomendaciones
#   * Ponga comentarios en su código para facilitar su comprensión.
#   * Utilice nombres claros y significativos para variables y funciones.
#   * Verifique que todas las celdas se ejecuten sin errores.
#   * Mantenga el notebook organizado y bien documentado.
#   * No dude en consultar en caso de dudas o dificultades.
#
# ### 6.	Evaluación
#   * Se evaluará que el código funcione correctamente y resuelva los problemas planteados.
#   * Se tomará en cuenta la claridad en la documentación y la organización del notebook.
#   * Se tomará en cuenta la nomenclatura de variables y funciones creadas. Estos nombres **deben** ser significativos. Por ejemplo, en vez de nombrar una variable `a`, nombrela con algo que represente su significado, como `nombre`, `edad_de_persona`, etc. Esto se exceptúa en los ejercicios en donde el mismo enunciado nombra las variables que se deben usar.
#   * **Debe poder ejecutarse el notebook de forma secuencial y que funcione correctamente (no se aceptará la ejecución de celdas en desorden para obtener el resultado deseado).**
#   * Cada ejercicio debe resolverse de manera **independiente**. Puede usar los mismos nombres de variables o funciones en distintos ejercicios, pero los valores de las variables (o resultados previos) **no se pueden reutilizar entre ejercicios salvo que se indique lo contrario en el enunciado del ejercicio**.
#
# #### Ejemplo de independencia entre ejercicios
#
# Lo incorrecto 🚫:
#
# | Ejercicio | Código | Comentario |
# |------------|-----------|--------|
# | 1 | x = 10<br>y = 5<br>suma = x + y<br>print(suma) | Calcula la suma correctamente |
# | 2 | doble = suma * 2<br>print(doble) | Reutiliza 'suma' del ejercicio 1, lo cual **no está permitido** |
#
# Lo correcto ✅:
#
# | Ejercicio | Código | Comentario |
# |------------|-----------|--------|
# | 1 | x = 10<br>y = 5<br>suma = x + y<br>print(suma) | Calcula la suma correctamente |
# | 2 | suma = 7 + 3<br>doble = suma * 2<br>print(doble) | No eutiliza 'suma' del ejercicio 1. Cada ejercicio se resuelve de manera independiente |

# %% [markdown]
# # Pruebas automáticas
#
# **EJECUTE LA CELDA DE ABAJO ANTES DE EMPEZAR A EJECUTAR SU CÓDIGO**
# Esto sirve para que pueda ejecutar casos de prueba sobre su código.
#
# ---

# %%
# !pip install --upgrade notebook-cell-tester --q

# %% [markdown]
# ---
#
# **Ejercicio 1**
#
# Construya un programa que determine si un número de tres cifras es igual a la suma de los **cubos de sus dígitos**.
#
# A estos números se les llama *números Armstrong* o *narcisistas*.
#
# El programa debe:
# 1. Leer un número entero de tres cifras.
# 2. Separar sus cifras. Usando operaciones matemáticas. No puede separarlo como un `str`.
# 3. Calcular $c_1^3$ + $c_2^3$ + $c_3^3$.
# 4. Comparar con el número original.
# 5. Imprimir "1" si cumple la condición, "0" si no.
#
# **Su programa tiene que ser resiliente a errores en la entrada de datos. Por ejemplo, si el usuario ingresa una hilera de texto en vez de un número, debe mostrar un mensaje que indique que el programa no se pudo ejecutar. No hace falta que pida el valor de nuevo si el usuario lo ingresa mal, puede terminar su programa como se indicó anteriormente.**
#
# Ejemplos:
#
# | Número | Cálculo       | Resultado |
# |--------|---------------|-----------|
# | 153    | 1³ + 5³ + 3³  | 1         |
# | 370    | 3³ + 7³ + 0³  | 1         |
# | 371    | 3³ + 7³ + 1³  | 1         |
# | 123    | 1³ + 2³ + 3³  | 0         |
#
# ---

# %%
# Acá su código

# %%
#@title Pruebas automáticas (solo ejecutar, no modificar)
from notebook_cell_tester.tester import ColabTestFramework, TestCase, TestSection

tester = ColabTestFramework()

tests = [
    TestSection("Sección 1 — Correctitud", [
        TestCase(
            name="153 es Armstrong (1³+5³+3³=153) → imprime 1",
            test_type="regex_output",
            stdin_input="153\n",
            pattern=r"(?<!\d)1(?!\d)",
            error_message="Para 153: 1³+5³+3³=1+125+27=153. El programa debe imprimir '1'. Revise que extrae los dígitos con operaciones matemáticas (// y %) y calcula los cubos con **."
        ),
        TestCase(
            name="370 es Armstrong (3³+7³+0³=370) → imprime 1",
            test_type="regex_output",
            stdin_input="370\n",
            pattern=r"(?<!\d)1(?!\d)",
            error_message="Para 370: 3³+7³+0³=27+343+0=370. Verifique que extrae el dígito de las decenas con (n // 10) % 10."
        ),
        TestCase(
            name="407 es Armstrong (4³+0³+7³=407) → imprime 1",
            test_type="regex_output",
            stdin_input="407\n",
            pattern=r"(?<!\d)1(?!\d)",
            error_message="Para 407: 4³+0³+7³=64+0+343=407. El dígito central es 0; asegúrese de que 0³=0 no causa problemas en su cálculo."
        ),
        TestCase(
            name="123 NO es Armstrong (1³+2³+3³=36≠123) → imprime 0",
            test_type="regex_output",
            stdin_input="123\n",
            pattern=r"(?<!\d)0(?!\d)",
            error_message="Para 123: 1³+2³+3³=1+8+27=36≠123. El programa debe imprimir '0'. Verifique que la comparación es entre la suma de cubos y el número original."
        ),
        TestCase(
            name="200 NO es Armstrong (2³+0³+0³=8≠200) → imprime 0",
            test_type="regex_output",
            stdin_input="200\n",
            pattern=r"(?<!\d)0(?!\d)",
            error_message="Para 200: 2³+0³+0³=8≠200. El programa debe imprimir '0'. Verifique la extracción de las decenas y unidades con // y %."
        ),
    ]),
    TestSection("Sección 3 — Manejo de errores", [
        TestCase(
            name="Entrada de texto ('hola') → mensaje de error visible",
            test_type="regex_output",
            stdin_input="hola\n",
            pattern=r"[a-zA-ZáéíóúÁÉÍÓÚñÑ]",
            error_message="Cuando el usuario ingresa texto, el programa debe mostrar un mensaje indicando que no pudo ejecutarse. Use try/except para capturar el ValueError que lanza int() con entrada no numérica."
        ),
    ]),
    TestSection("Sección 4 — Estructura del código", [
        TestCase(
            name="Usa división entera (//) para extraer dígitos",
            test_type="regex",
            pattern=r"//",
            error_message="Extraiga los dígitos con operaciones matemáticas, no convirtiendo el número a str. Use '//' para obtener la centena: n // 100."
        ),
        TestCase(
            name="Usa módulo (%) para extraer dígitos",
            test_type="regex",
            pattern=r"%",
            error_message="Extraiga los dígitos con operaciones matemáticas. Use '%' para la unidad (n % 10) y las decenas ((n // 10) % 10)."
        ),
    ]),
]

tester.run_sections(tests)
tester.display_results()

# %% [markdown]
# ---
#
# **Ejercicio 2**
#
# En un curso de nivel universitario se desea calcular de manera automatizada el **promedio final** de un estudiante.
# El sistema de evaluación considera:
#
# - Tres **prácticas calificadas** (P1, P2, P3).
# - Un **examen parcial** (EP).
# - Un **examen final** (EF).
#
# El promedio de prácticas (PP) se calcula como:
#
# $$
# PP = \frac{P1 + P2 + P3}{3}
# $$
#
# El promedio final del curso (PROM) se calcula ponderando las notas así:
#
# $$
# PROM = \frac{PP + 2 \times EP + 3 \times EF}{6}
# $$
#
# **El programa debe:**
# 1. Leer las cinco notas: P1, P2, P3, EP y EF. Puede leer las 5 notas por separado. Tome en cuenta que pueden ser números reales y no solo enteros.
# 2. Calcular PP usando la fórmula indicada.
# 3. Calcular el promedio final PROM.
# 4. Mostrar el valor obtenido de PROM como resultado. Utilice únicamente 2 decimales.
#
# **Su programa tiene que ser resiliente a errores en la entrada de datos. Por ejemplo, si el usuario ingresa una hilera de texto en vez de un número, debe mostrar un mensaje que indique que el programa no se pudo ejecutar.**
#
# Ejemplo:
#
# | P1 | P2 | P3 | EP | EF | PP   | PROM  |
# |----|----|----|----|----|------|-------|
# | 10 | 12 | 14 | 15 | 18 | 12.0 | 16.00  |
#
# ---

# %%
# Acá su código

# %%
#@title Pruebas automáticas (solo ejecutar, no modificar)
from notebook_cell_tester.tester import ColabTestFramework, TestCase, TestSection

tester = ColabTestFramework()

tests = [
    TestSection("Sección 1 — Correctitud", [
        TestCase(
            name="P1=10, P2=12, P3=14, EP=15, EF=18 → PROM=16.00",
            test_type="regex_output",
            stdin_input="10\n12\n14\n15\n18\n",
            pattern=r"16\.00(?!\d)",
            error_message="Con P1=10, P2=12, P3=14, EP=15, EF=18: PP=(10+12+14)/3=12.0 y PROM=(12.0+2×15+3×18)/6=96/6=16.00. Revise la fórmula y que el resultado se muestra con exactamente 2 decimales."
        ),
        TestCase(
            name="P1=8, P2=6, P3=10, EP=12, EF=15 → PROM=12.83",
            test_type="regex_output",
            stdin_input="8\n6\n10\n12\n15\n",
            pattern=r"12\.83(?!\d)",
            error_message="Con P1=8, P2=6, P3=10, EP=12, EF=15: PP=8.0 y PROM=(8.0+24+45)/6=77/6≈12.83. Verifique la ponderación: 1×PP + 2×EP + 3×EF dividido entre 6."
        ),
        TestCase(
            name="Notas decimales: P1=7.5, P2=8.5, P3=9.0, EP=10.0, EF=12.0 → PROM=10.72",
            test_type="regex_output",
            stdin_input="7.5\n8.5\n9.0\n10.0\n12.0\n",
            pattern=r"10\.72(?!\d)",
            error_message="Con notas decimales: PP≈8.333 y PROM≈10.72. Use float() para leer las notas en lugar de int(); de lo contrario se pierden los valores decimales."
        ),
    ]),
    TestSection("Sección 2 — Casos extremos", [
        TestCase(
            name="Todas las notas en cero → PROM=0.00",
            test_type="regex_output",
            stdin_input="0\n0\n0\n0\n0\n",
            pattern=r"0\.00(?!\d)",
            error_message="Con todas las notas en 0, el promedio debe ser 0.00. Asegúrese de que la fórmula funciona con valores cero y que siempre se muestran 2 decimales."
        ),
    ]),
    TestSection("Sección 3 — Manejo de errores", [
        TestCase(
            name="Entrada de texto → mensaje de error visible",
            test_type="regex_output",
            stdin_input="texto\n",
            pattern=r"[a-zA-ZáéíóúÁÉÍÓÚñÑ]",
            error_message="Si el usuario ingresa texto en lugar de un número, el programa debe mostrar un mensaje de error. Use try/except para capturar el ValueError que lanza float() con entrada no numérica."
        ),
    ]),
]

tester.run_sections(tests)
tester.display_results()

# %% [markdown]
# ---
#
# **Ejercicio 3**
#
# En lógica y en programación, el operador **XOR** (exclusive OR, "o exclusivo") combina dos valores lógicos (verdadero o falso) y devuelve **verdadero solo si exactamente uno de ellos es verdadero**.
#
# En otras palabras:
# - `True XOR True` → `False`
# - `True XOR False` → `True`
# - `False XOR True` → `True`
# - `False XOR False` → `False`
#
# Hacer un `XOR` entre dos variables booleanas `A` y `B`, es equivalente a evaluar la expresión
#
# > [(`A` y no `B`) o (no `A` y `B`)].
#
# **El programa debe:**
# 1. Leer dos valores lógicos del usuario en una variable `A` y una variable `B` (por ejemplo, `True` o `False`). Recuerde que en Python, `bool(input("Ingrese algo: "))` devuelve `True` siempre que la hilera ingresada no sea vacía. Por lo tanto, haga que el usuario ingrese un 0 o un 1, conviértalo a un entero y luego convierta el entero a un booleano.
# 2. Implementar la expresión de equivalencia del `XOR` usando operadores lógicos únicamente (not, and, or).
# 3. Muestre en pantalla el resultado de la expresión, como `True` o `False`.
# 4. Utilice un `assert` para verificar que su expresión está correcta, poniendo de casos de prueba a los 4 que vienen en la tabla de abajo. Utilice el operador `^` que python tiene integrado (es el XOR) para comparar si el resultado de su expresión es igual a `A ^ B`. Pruebe su programa cambiando los valores de `A` y `B`. Su programa no debe arrojar un error en el assert si la implementación fue correcta.
#
# | A     | B     | A XOR B |
# |-------|-------|-------|
# | False | False | False |
# | False | True  | True  |
# | True  | False | True  |
# | True  | True  | False |
#
# ---

# %%
# Acá su código

# %%
#@title Pruebas automáticas (solo ejecutar, no modificar)
from notebook_cell_tester.tester import ColabTestFramework, TestCase, TestSection

tester = ColabTestFramework()

tests = [
    TestSection("Sección 1 — Correctitud", [
        TestCase(
            name="A=0 (False), B=0 (False) → False XOR False = False",
            test_type="regex_output",
            stdin_input="0\n0\n",
            pattern=r"(?i)\bfalse\b",
            error_message="Con A=False y B=False, el XOR debe dar False. Ninguna de las sub-expresiones (A and not B) ni (not A and B) es verdadera cuando ambos son False."
        ),
        TestCase(
            name="A=0 (False), B=1 (True) → False XOR True = True",
            test_type="regex_output",
            stdin_input="0\n1\n",
            pattern=r"(?i)\btrue\b",
            error_message="Con A=False y B=True, el XOR debe dar True. La sub-expresión (not A and B) es verdadera: not False and True = True."
        ),
        TestCase(
            name="A=1 (True), B=0 (False) → True XOR False = True",
            test_type="regex_output",
            stdin_input="1\n0\n",
            pattern=r"(?i)\btrue\b",
            error_message="Con A=True y B=False, el XOR debe dar True. La sub-expresión (A and not B) es verdadera: True and not False = True."
        ),
        TestCase(
            name="A=1 (True), B=1 (True) → True XOR True = False",
            test_type="regex_output",
            stdin_input="1\n1\n",
            pattern=r"(?i)\bfalse\b",
            error_message="Con A=True y B=True, el XOR debe dar False. Ni (A and not B) ni (not A and B) es verdadera cuando ambos son True."
        ),
    ]),
    TestSection("Sección 4 — Estructura del código", [
        TestCase(
            name="Usa el operador lógico 'not'",
            test_type="regex",
            pattern=r"\bnot\b",
            error_message="La implementación del XOR requiere 'not'. Use la expresión equivalente: (A and not B) or (not A and B)."
        ),
        TestCase(
            name="Usa el operador lógico 'and'",
            test_type="regex",
            pattern=r"\band\b",
            error_message="La implementación del XOR requiere 'and'. Use la expresión equivalente: (A and not B) or (not A and B)."
        ),
        TestCase(
            name="Usa el operador lógico 'or'",
            test_type="regex",
            pattern=r"\bor\b",
            error_message="La implementación del XOR requiere 'or'. Use la expresión equivalente: (A and not B) or (not A and B)."
        ),
        TestCase(
            name="Usa 'assert' para verificar la expresión",
            test_type="regex",
            pattern=r"\bassert\b",
            error_message="El ejercicio pide usar 'assert' para verificar que la expresión XOR coincide con el operador ^ de Python. Agregue algo como: assert resultado == A ^ B."
        ),
    ]),
]

tester.run_sections(tests)
tester.display_results()

# %% [markdown]
# ---
#
# **Ejercicio 4**
#
# Un profesor quiere mostrar un **reporte bonito** con las calificaciones de un estudiante en varias asignaturas.
# Pida el nombre del alumno, el nombre de 3 asignaturas, y la nota de cada una de esas asignaturas. Un ejemplo de estos datos es:
#
# ```python
# alumno = "Ana Pérez"
# asignatura1 = "Matemáticas"
# nota1 = 9.5
#
# asignatura2 = "Historia"
# nota2 = 8.0
#
# asignatura3 = "Ciencias"
# nota3 = 7.75
# ```
#
# El programa tiene que pedir este tipo de datos por medio de `input()`.
# El programa debe dar la siguiente salida:
#
# ```txt
# ===============================
#        REPORTE DE NOTAS
# ===============================
# Alumno: Ana Pérez
# -------------------------------
# Matemáticas       :  9.50
# Historia          :  8.00
# Ciencias          :  7.75
# -------------------------------
# Promedio          :  8.42
# ===============================
# ```
#
# ---

# %%
# Acá su código

# %%
#@title Pruebas automáticas (solo ejecutar, no modificar)
from notebook_cell_tester.tester import ColabTestFramework, TestCase, TestSection

tester = ColabTestFramework()

# stdin asume el orden: nombre alumno, nombre asignatura 1, nota 1,
#                       nombre asignatura 2, nota 2, nombre asignatura 3, nota 3
tests = [
    TestSection("Sección 1 — Correctitud", [
        TestCase(
            name="Reporte contiene encabezado y nombre del alumno",
            test_type="multiline_output",
            stdin_input="Ana Pérez\nMatemáticas\n9.5\nHistoria\n8.0\nCiencias\n7.75\n",
            expected=["REPORTE DE NOTAS", "Ana Pérez"],
            error_message="El reporte debe incluir el título 'REPORTE DE NOTAS' y el nombre del alumno. Revise el encabezado del reporte."
        ),
        TestCase(
            name="Notas de Ana Pérez aparecen con 2 decimales",
            test_type="multiline_output",
            stdin_input="Ana Pérez\nMatemáticas\n9.5\nHistoria\n8.0\nCiencias\n7.75\n",
            expected=["9.50", "8.00", "7.75"],
            error_message="Las notas deben mostrarse con exactamente 2 decimales: 9.5→'9.50', 8.0→'8.00', 7.75→'7.75'. Use formato :.2f en sus f-strings o con .format()."
        ),
        TestCase(
            name="Promedio de Ana Pérez es 8.42",
            test_type="regex_output",
            stdin_input="Ana Pérez\nMatemáticas\n9.5\nHistoria\n8.0\nCiencias\n7.75\n",
            pattern=r"8\.42(?!\d)",
            error_message="El promedio (9.5+8.0+7.75)/3=25.25/3≈8.4167 redondeado a 2 decimales es 8.42. Verifique el cálculo y el formato."
        ),
        TestCase(
            name="El reporte usa separadores '=====' y '-----'",
            test_type="regex_output",
            stdin_input="Ana Pérez\nMatemáticas\n9.5\nHistoria\n8.0\nCiencias\n7.75\n",
            pattern=r"={5,}.*-{5,}",
            error_message="El reporte debe incluir líneas de '=====' y '-----' como separadores. Revise el formato del ejemplo en el enunciado."
        ),
        TestCase(
            name="Reporte con Pedro Castro (verifica que no hay valores hardcodeados)",
            test_type="multiline_output",
            stdin_input="Pedro Castro\nArte\n6.0\nMúsica\n9.0\nDeporte\n8.0\n",
            expected=["Pedro Castro", "6.00", "9.00", "8.00", "7.67"],
            error_message="Con Pedro Castro y notas 6.0, 9.0, 8.0: el promedio (6+9+8)/3≈7.67. Verifique que el programa funciona con cualquier entrada y no tiene valores hardcodeados."
        ),
    ]),
]

tester.run_sections(tests)
tester.display_results()
